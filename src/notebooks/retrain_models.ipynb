# %%
import os
import sys
sys.path.append('../')
import logging
import numpy as np
import optuna
from joblib import dump, load

# %%
from util import load_pkl, get_pipline_rf, get_pipline_svr
logger = logging.getLogger('inference')
logger.setLevel(logging.DEBUG)  # Set the logging level

# Prevent adding multiple handlers if this cell is run multiple times
if not logger.handlers:
    # Create a handler that outputs to standard output
    handler = logging.StreamHandler(sys.stdout)

    # Define the log message format
    formatter = logging.Formatter(
        '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
    )
    handler.setFormatter(formatter)

    # Add the handler to the logger
    logger.addHandler(handler)

# %%
logger.debug("This is a debug message.")
# Out:
# 2025-04-27 00:30:59,589 - inference - DEBUG - This is a debug message.

# %%
period = 128
data_dir = f'../../processed_data/processed_data_{period}'

# %%
df_train_X_all = load_pkl(f"{data_dir}/df_train_X_all.pkl")
df_train_y_all = load_pkl(f"{data_dir}/df_train_y_all.pkl")
df_test_X_all = load_pkl(f"{data_dir}/df_test_X_all.pkl")
df_test_y_all = load_pkl(f"{data_dir}/df_test_y_all.pkl")

# %%
# load the valid tickers.
with open(f'{data_dir}/valid_tickers.txt', 'r') as f:
    valid_tickers = f.readlines()

# %%
print(f'Data preparation finished, found {len(valid_tickers)} assets with enough data.')
feature_file_path = os.path.join(data_dir, 'sorted_features.txt')

with open(feature_file_path, 'r') as file:
  sorted_features = np.array(file.read().split('\n'))
  sorted_features = sorted_features[sorted_features != '']
# Out:
# Data preparation finished, found 746 assets with enough data.

# %%
for i in range(len(valid_tickers)):
  df_train_X_all[i] = df_train_X_all[i][sorted_features]
  df_test_X_all[i] = df_test_X_all[i][sorted_features]

# %%
# You can load it back into memory with the following code
# mysql_url = "mysql://root@192.168.2.34:3306/mysql"
postgres_url = "postgresql+psycopg2://postgres:example@192.168.2.34:5432/app_db"
n_columns = len(df_train_X_all[0].columns)
study_rf_name = f'study_rf_columns_{n_columns}_stocks_{len(valid_tickers)}_period_{period}'
study_rf = optuna.create_study(study_name=study_rf_name, storage=postgres_url, load_if_exists=True)
if study_rf.best_trial is None:
  logger.error('No best trial found')
  sys.exit(2)

study_svm_name = f'study_svm_columns_{n_columns}_stocks_{len(valid_tickers)}_period_{period}'
study_svm = optuna.create_study(study_name=study_svm_name, storage=postgres_url, load_if_exists=True)
if study_svm.best_trial is None:
  logger.error('No best trial found')
  sys.exit(2)
# Out:
# [I 2025-04-27 00:23:11,587] Using an existing study with name 'study_rf_columns_28_stocks_746_period_128' instead of creating a new one.
# [I 2025-04-27 00:23:11,741] Using an existing study with name 'study_svm_columns_28_stocks_746_period_128' instead of creating a new one.

# %%
best_pipeline_rf = get_pipline_rf(study_rf.best_params)
best_pipeline_svr = get_pipline_svr(study_svm.best_params)

# %%
for filename in os.listdir(f'{data_dir}/models'):
  if filename.endswith('.pkl'):
    os.remove(os.path.join(f'{data_dir}/models', filename))

# %%
from joblib import dump, load

for i in range(len(valid_tickers)):
  stock_name = valid_tickers[i].strip()
  df_train_X = df_train_X_all[i]
  df_train_y = df_train_y_all[i]
  df_test_X = df_test_X_all[i]
  df_test_y = df_test_y_all[i]

  X_train = df_train_X.copy().values
  y_train = df_train_y.copy().values.ravel()
  X_test = df_test_X.copy().values
  y_test = df_test_y.copy().values.ravel()

  if not os.path.exists(f'{data_dir}/models'):
    os.makedirs(f'{data_dir}/models')


  best_pipeline_rf = get_pipline_rf(study_rf.best_params)
  best_pipeline_rf.fit(X_train, y_train)

  # save the model using joblib

  dump(best_pipeline_rf, f'{data_dir}/models/{stock_name}_rf.joblib')
  logger.info(f"Model for {stock_name} saved successfully.")

  best_pipeline_svr = get_pipline_svr(study_svm.best_params)
  best_pipeline_svr.fit(X_train, y_train)

  # save the model using joblib
  dump(best_pipeline_svr, f'{data_dir}/models/{stock_name}_svr.joblib')
  logger.info(f"Model for {stock_name} saved successfully.")

# %%
for i in range(len(valid_tickers)):
  stock_name = valid_tickers[i].strip()
  df_train_X = df_train_X_all[i]
  df_train_y = df_train_y_all[i]
  df_test_X = df_test_X_all[i]
  df_test_y = df_test_y_all[i]

  X_train = df_train_X.copy().values
  y_train = df_train_y.copy().values.ravel()
  X_test = df_test_X.copy().values
  y_test = df_test_y.copy().values.ravel()

  # load the model using joblib
  loaded_model_rf = load(f'{data_dir}/models/{stock_name}_rf.joblib')

  # make predictions using the loaded model
  predictions_rf = loaded_model_rf.predict(X_test)
  loaded_model_svr = load(f'{data_dir}/models/{stock_name}_svr.joblib')
  predictions_svr = loaded_model_svr.predict(X_test)
  logger.info(f"Predictions for {stock_name} made successfully.")

# %%
import requests
import joblib
from io import BytesIO

# Define the base URL for your Azure Blob Storage
base_url = 'https://stockmodels.blob.core.windows.net/models/'

for i in range(len(valid_tickers)):
    stock_name = valid_tickers[i].strip()
    df_train_X = df_train_X_all[i]
    df_train_y = df_train_y_all[i]
    df_test_X = df_test_X_all[i]
    df_test_y = df_test_y_all[i]

    X_train = df_train_X.copy().values
    y_train = df_train_y.copy().values.ravel()
    X_test = df_test_X.copy().values
    y_test = df_test_y.copy().values.ravel()

    # Construct the full URL for the model
    model_filename = f'{stock_name}_rf.joblib'
    model_url = f'{base_url}{model_filename}'

    try:
        # Send a GET request to download the model file
        response = requests.get(model_url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Load the model from the downloaded content
        model_bytes = BytesIO(response.content)
        loaded_model_rf = joblib.load(model_bytes)

        # Make predictions using the loaded model
        predictions_rf = loaded_model_rf.predict(X_test)
        logger.info(f"Predictions for {stock_name} made successfully.")
        # (Optional) You can add your evaluation metrics here
        # For example:
        # from sklearn.metrics import mean_squared_error
        # mse = mean_squared_error(y_test, predictions_rf)
        # print(f'MSE for {stock_name}: {mse}')

    except requests.exceptions.HTTPError as http_err:
        print(f'HTTP error occurred while downloading {model_filename}: {http_err}')
    except Exception as err:
        print(f'An error occurred while processing {model_filename}: {err}')
# Out:
# 2025-04-27 11:21:06,227 - inference - INFO - Predictions for ADS.DE made successfully.
# 2025-04-27 11:21:06,312 - inference - INFO - Predictions for AIR.DE made successfully.
# 2025-04-27 11:21:06,407 - inference - INFO - Predictions for ALV.DE made successfully.
# 2025-04-27 11:21:06,494 - inference - INFO - Predictions for BAS.DE made successfully.
# 2025-04-27 11:21:06,573 - inference - INFO - Predictions for BAYN.DE made successfully.
# 2025-04-27 11:21:06,656 - inference - INFO - Predictions for BEI.DE made successfully.
# 2025-04-27 11:21:06,731 - inference - INFO - Predictions for BMW.DE made successfully.
# 2025-04-27 11:21:06,804 - inference - INFO - Predictions for BNR.DE made successfully.
# 2025-04-27 11:21:06,883 - inference - INFO - Predictions for CBK.DE made successfully.
# 2025-04-27 11:21:06,969 - inference - INFO - Predictions for CON.DE made successfully.
# 2025-04-27 11:21:07,056 - inference - INFO - Predictions for DBK.DE made successfully.
# 2025-04-27 11:21:07,138 - inference - INFO - Predictions for DB1.DE made successfully.
# 2025-04-27 11:21:07,227 - inference - INFO - Predictions for DHL.DE made successfully.
# 2025-04-27 11:21:07,312 - inference - INFO - Predictions for DTE.DE made successfully.
# 2025-04-27 11:21:07,391 - inference - INFO - Predictions for EOAN.DE made successfully.
# 2025-04-27 11:21:07,479 - inference - INFO - Predictions for FRE.DE made successfully.
# 2025-04-27 11:21:07,564 - inference - INFO - Predictions for HNR1.DE made successfully.
# 2025-04-27 11:21:07,639 - inference - INFO - Predictions for HEI.DE made successfully.
# 2025-04-27 11:21:07,716 - inference - INFO - Predictions for HEN3.DE made successfully.
# 2025-04-27 11:21:07,803 - inference - INFO - Predictions for IFX.DE made successfully.
# 2025-04-27 11:21:07,884 - inference - INFO - Predictions for MBG.DE made successfully.
# 2025-04-27 11:21:07,967 - inference - INFO - Predictions for MRK.DE made successfully.
# 2025-04-27 11:21:08,047 - inference - INFO - Predictions for MTX.DE made successfully.
# 2025-04-27 11:21:08,131 - inference - INFO - Predictions for MUV2.DE made successfully.
# 2025-04-27 11:21:08,207 - inference - INFO - Predictions for PAH3.DE made successfully.
# 2025-04-27 11:21:08,285 - inference - INFO - Predictions for QIA.DE made successfully.
# 2025-04-27 11:21:08,364 - inference - INFO - Predictions for RHM.DE made successfully.
# 2025-04-27 11:21:08,450 - inference - INFO - Predictions for RWE.DE made successfully.
# 2025-04-27 11:21:08,531 - inference - INFO - Predictions for SAP.DE made successfully.
# 2025-04-27 11:21:08,613 - inference - INFO - Predictions for SRT3.DE made successfully.
# 2025-04-27 11:21:08,698 - inference - INFO - Predictions for SIE.DE made successfully.
# 2025-04-27 11:21:08,779 - inference - INFO - Predictions for SY1.DE made successfully.
# 2025-04-27 11:21:08,859 - inference - INFO - Predictions for VOW3.DE made successfully.
# 2025-04-27 11:21:08,944 - inference - INFO - Predictions for VNA.DE made successfully.
# 2025-04-27 11:21:09,025 - inference - INFO - Predictions for III.L made successfully.
# 2025-04-27 11:21:09,118 - inference - INFO - Predictions for ADM.L made successfully.
# 2025-04-27 11:21:09,203 - inference - INFO - Predictions for AAL.L made successfully.
# 2025-04-27 11:21:09,286 - inference - INFO - Predictions for ANTO.L made successfully.
# 2025-04-27 11:21:09,362 - inference - INFO - Predictions for AHT.L made successfully.
# 2025-04-27 11:21:09,460 - inference - INFO - Predictions for ABF.L made successfully.
# 2025-04-27 11:21:09,541 - inference - INFO - Predictions for AZN.L made successfully.
# 2025-04-27 11:21:09,619 - inference - INFO - Predictions for AV.L made successfully.
# 2025-04-27 11:21:09,696 - inference - INFO - Predictions for BA.L made successfully.
# 2025-04-27 11:21:09,773 - inference - INFO - Predictions for BARC.L made successfully.
# 2025-04-27 11:21:09,850 - inference - INFO - Predictions for BDEV.L made successfully.
# 2025-04-27 11:21:09,938 - inference - INFO - Predictions for BEZ.L made successfully.
# 2025-04-27 11:21:10,034 - inference - INFO - Predictions for BKG.L made successfully.
# 2025-04-27 11:21:10,119 - inference - INFO - Predictions for BP.L made successfully.
# 2025-04-27 11:21:10,201 - inference - INFO - Predictions for BATS.L made successfully.
# 2025-04-27 11:21:10,286 - inference - INFO - Predictions for BT-A.L made successfully.
# 2025-04-27 11:21:10,362 - inference - INFO - Predictions for BNZL.L made successfully.
# 2025-04-27 11:21:10,449 - inference - INFO - Predictions for BRBY.L made successfully.
# 2025-04-27 11:21:10,533 - inference - INFO - Predictions for CNA.L made successfully.
# 2025-04-27 11:21:10,616 - inference - INFO - Predictions for CCH.L made successfully.
# 2025-04-27 11:21:10,698 - inference - INFO - Predictions for CPG.L made successfully.
# 2025-04-27 11:21:10,784 - inference - INFO - Predictions for CRDA.L made successfully.
# 2025-04-27 11:21:10,864 - inference - INFO - Predictions for DCC.L made successfully.
# 2025-04-27 11:21:10,944 - inference - INFO - Predictions for DGE.L made successfully.
# 2025-04-27 11:21:11,029 - inference - INFO - Predictions for DPLM.L made successfully.
# 2025-04-27 11:21:11,108 - inference - INFO - Predictions for ENT.L made successfully.
# 2025-04-27 11:21:11,185 - inference - INFO - Predictions for EZJ.L made successfully.
# 2025-04-27 11:21:11,264 - inference - INFO - Predictions for EXPN.L made successfully.
# 2025-04-27 11:21:11,359 - inference - INFO - Predictions for FCIT.L made successfully.
# 2025-04-27 11:21:11,439 - inference - INFO - Predictions for FLTR.L made successfully.
# 2025-04-27 11:21:11,522 - inference - INFO - Predictions for FRAS.L made successfully.
# 2025-04-27 11:21:11,605 - inference - INFO - Predictions for FRES.L made successfully.
# 2025-04-27 11:21:11,684 - inference - INFO - Predictions for GLEN.L made successfully.
# 2025-04-27 11:21:11,773 - inference - INFO - Predictions for GSK.L made successfully.
# 2025-04-27 11:21:11,859 - inference - INFO - Predictions for HLMA.L made successfully.
# 2025-04-27 11:21:11,946 - inference - INFO - Predictions for HIK.L made successfully.
# 2025-04-27 11:21:12,039 - inference - INFO - Predictions for HWDN.L made successfully.
# 2025-04-27 11:21:12,115 - inference - INFO - Predictions for HSBA.L made successfully.
# 2025-04-27 11:21:12,197 - inference - INFO - Predictions for IHG.L made successfully.
# 2025-04-27 11:21:12,280 - inference - INFO - Predictions for IMI.L made successfully.
# 2025-04-27 11:21:12,360 - inference - INFO - Predictions for IMB.L made successfully.
# 2025-04-27 11:21:12,445 - inference - INFO - Predictions for INF.L made successfully.
# 2025-04-27 11:21:12,525 - inference - INFO - Predictions for ICP.L made successfully.
# 2025-04-27 11:21:12,604 - inference - INFO - Predictions for IAG.L made successfully.
# 2025-04-27 11:21:12,686 - inference - INFO - Predictions for ITRK.L made successfully.
# 2025-04-27 11:21:12,764 - inference - INFO - Predictions for JD.L made successfully.
# 2025-04-27 11:21:12,845 - inference - INFO - Predictions for KGF.L made successfully.
# 2025-04-27 11:21:12,924 - inference - INFO - Predictions for LAND.L made successfully.
# 2025-04-27 11:21:12,994 - inference - INFO - Predictions for LGEN.L made successfully.
# 2025-04-27 11:21:13,077 - inference - INFO - Predictions for LLOY.L made successfully.
# 2025-04-27 11:21:13,161 - inference - INFO - Predictions for LSEG.L made successfully.
# 2025-04-27 11:21:13,238 - inference - INFO - Predictions for MKS.L made successfully.
# 2025-04-27 11:21:13,318 - inference - INFO - Predictions for MRO.L made successfully.
# 2025-04-27 11:21:13,400 - inference - INFO - Predictions for MNDI.L made successfully.
# 2025-04-27 11:21:13,477 - inference - INFO - Predictions for NG.L made successfully.
# 2025-04-27 11:21:13,550 - inference - INFO - Predictions for NWG.L made successfully.
# 2025-04-27 11:21:13,631 - inference - INFO - Predictions for NXT.L made successfully.
# 2025-04-27 11:21:13,705 - inference - INFO - Predictions for OCDO.L made successfully.
# 2025-04-27 11:21:13,783 - inference - INFO - Predictions for PSON.L made successfully.
# 2025-04-27 11:21:13,870 - inference - INFO - Predictions for PSN.L made successfully.
# 2025-04-27 11:21:13,950 - inference - INFO - Predictions for PHNX.L made successfully.
# 2025-04-27 11:21:14,030 - inference - INFO - Predictions for PRU.L made successfully.
# 2025-04-27 11:21:14,111 - inference - INFO - Predictions for RKT.L made successfully.
# 2025-04-27 11:21:14,198 - inference - INFO - Predictions for REL.L made successfully.
# 2025-04-27 11:21:14,281 - inference - INFO - Predictions for RTO.L made successfully.
# 2025-04-27 11:21:14,358 - inference - INFO - Predictions for RMV.L made successfully.
# 2025-04-27 11:21:14,432 - inference - INFO - Predictions for RIO.L made successfully.
# 2025-04-27 11:21:14,514 - inference - INFO - Predictions for RR.L made successfully.
# 2025-04-27 11:21:14,594 - inference - INFO - Predictions for RS1.L made successfully.
# 2025-04-27 11:21:14,668 - inference - INFO - Predictions for SGE.L made successfully.
# 2025-04-27 11:21:14,744 - inference - INFO - Predictions for SBRY.L made successfully.
# 2025-04-27 11:21:14,817 - inference - INFO - Predictions for SDR.L made successfully.
# 2025-04-27 11:21:14,901 - inference - INFO - Predictions for SMT.L made successfully.
# 2025-04-27 11:21:14,980 - inference - INFO - Predictions for SGRO.L made successfully.
# 2025-04-27 11:21:15,065 - inference - INFO - Predictions for SVT.L made successfully.
# 2025-04-27 11:21:15,142 - inference - INFO - Predictions for SHEL.L made successfully.
# 2025-04-27 11:21:15,226 - inference - INFO - Predictions for SMDS.L made successfully.
# 2025-04-27 11:21:15,306 - inference - INFO - Predictions for SMIN.L made successfully.
# 2025-04-27 11:21:15,388 - inference - INFO - Predictions for SN.L made successfully.
# 2025-04-27 11:21:15,471 - inference - INFO - Predictions for SKG.L made successfully.
# 2025-04-27 11:21:15,549 - inference - INFO - Predictions for SPX.L made successfully.
# 2025-04-27 11:21:15,629 - inference - INFO - Predictions for SSE.L made successfully.
# 2025-04-27 11:21:15,709 - inference - INFO - Predictions for STAN.L made successfully.
# 2025-04-27 11:21:15,790 - inference - INFO - Predictions for STJ.L made successfully.
# 2025-04-27 11:21:15,872 - inference - INFO - Predictions for TW.L made successfully.
# 2025-04-27 11:21:15,953 - inference - INFO - Predictions for TSCO.L made successfully.
# 2025-04-27 11:21:16,030 - inference - INFO - Predictions for ULVR.L made successfully.
# 2025-04-27 11:21:16,106 - inference - INFO - Predictions for UU.L made successfully.
# 2025-04-27 11:21:16,187 - inference - INFO - Predictions for UTG.L made successfully.
# 2025-04-27 11:21:16,266 - inference - INFO - Predictions for VOD.L made successfully.
# 2025-04-27 11:21:16,354 - inference - INFO - Predictions for WEIR.L made successfully.
# 2025-04-27 11:21:16,435 - inference - INFO - Predictions for WTB.L made successfully.
# 2025-04-27 11:21:16,514 - inference - INFO - Predictions for WPP.L made successfully.
# 2025-04-27 11:21:16,595 - inference - INFO - Predictions for MMM made successfully.
# 2025-04-27 11:21:16,689 - inference - INFO - Predictions for AOS made successfully.
# 2025-04-27 11:21:16,771 - inference - INFO - Predictions for ABT made successfully.
# 2025-04-27 11:21:16,883 - inference - INFO - Predictions for ABBV made successfully.
# 2025-04-27 11:21:16,964 - inference - INFO - Predictions for ACN made successfully.
# 2025-04-27 11:21:17,050 - inference - INFO - Predictions for ADBE made successfully.
# 2025-04-27 11:21:17,141 - inference - INFO - Predictions for AMD made successfully.
# 2025-04-27 11:21:17,219 - inference - INFO - Predictions for AES made successfully.
# 2025-04-27 11:21:17,296 - inference - INFO - Predictions for AFL made successfully.
# 2025-04-27 11:21:17,375 - inference - INFO - Predictions for A made successfully.
# 2025-04-27 11:21:17,445 - inference - INFO - Predictions for APD made successfully.
# 2025-04-27 11:21:17,526 - inference - INFO - Predictions for AKAM made successfully.
# 2025-04-27 11:21:17,604 - inference - INFO - Predictions for ALB made successfully.
# 2025-04-27 11:21:17,678 - inference - INFO - Predictions for ARE made successfully.
# 2025-04-27 11:21:17,755 - inference - INFO - Predictions for ALGN made successfully.
# 2025-04-27 11:21:17,834 - inference - INFO - Predictions for ALLE made successfully.
# 2025-04-27 11:21:17,911 - inference - INFO - Predictions for LNT made successfully.
# 2025-04-27 11:21:17,995 - inference - INFO - Predictions for ALL made successfully.
# 2025-04-27 11:21:18,070 - inference - INFO - Predictions for GOOGL made successfully.
# 2025-04-27 11:21:18,150 - inference - INFO - Predictions for GOOG made successfully.
# 2025-04-27 11:21:18,227 - inference - INFO - Predictions for MO made successfully.
# 2025-04-27 11:21:18,303 - inference - INFO - Predictions for AMZN made successfully.
# 2025-04-27 11:21:18,382 - inference - INFO - Predictions for AMCR made successfully.
# 2025-04-27 11:21:18,468 - inference - INFO - Predictions for AEE made successfully.
# 2025-04-27 11:21:18,548 - inference - INFO - Predictions for AAL made successfully.
# 2025-04-27 11:21:18,621 - inference - INFO - Predictions for AEP made successfully.
# 2025-04-27 11:21:18,694 - inference - INFO - Predictions for AXP made successfully.
# 2025-04-27 11:21:18,771 - inference - INFO - Predictions for AIG made successfully.
# 2025-04-27 11:21:18,848 - inference - INFO - Predictions for AMT made successfully.
# 2025-04-27 11:21:18,929 - inference - INFO - Predictions for AWK made successfully.
# 2025-04-27 11:21:19,003 - inference - INFO - Predictions for AMP made successfully.
# 2025-04-27 11:21:19,075 - inference - INFO - Predictions for AME made successfully.
# 2025-04-27 11:21:19,153 - inference - INFO - Predictions for AMGN made successfully.
# 2025-04-27 11:21:19,236 - inference - INFO - Predictions for APH made successfully.
# 2025-04-27 11:21:19,314 - inference - INFO - Predictions for ADI made successfully.
# 2025-04-27 11:21:19,388 - inference - INFO - Predictions for ANSS made successfully.
# 2025-04-27 11:21:19,474 - inference - INFO - Predictions for AON made successfully.
# 2025-04-27 11:21:19,546 - inference - INFO - Predictions for APA made successfully.
# 2025-04-27 11:21:19,629 - inference - INFO - Predictions for AAPL made successfully.
# 2025-04-27 11:21:19,705 - inference - INFO - Predictions for AMAT made successfully.
# 2025-04-27 11:21:19,781 - inference - INFO - Predictions for APTV made successfully.
# 2025-04-27 11:21:19,865 - inference - INFO - Predictions for ACGL made successfully.
# 2025-04-27 11:21:19,948 - inference - INFO - Predictions for ADM made successfully.
# 2025-04-27 11:21:20,026 - inference - INFO - Predictions for AJG made successfully.
# 2025-04-27 11:21:20,111 - inference - INFO - Predictions for AIZ made successfully.
# 2025-04-27 11:21:20,193 - inference - INFO - Predictions for T made successfully.
# 2025-04-27 11:21:20,275 - inference - INFO - Predictions for ATO made successfully.
# 2025-04-27 11:21:20,357 - inference - INFO - Predictions for ADSK made successfully.
# 2025-04-27 11:21:20,435 - inference - INFO - Predictions for ADP made successfully.
# 2025-04-27 11:21:20,517 - inference - INFO - Predictions for AZO made successfully.
# 2025-04-27 11:21:20,596 - inference - INFO - Predictions for AVB made successfully.
# 2025-04-27 11:21:20,672 - inference - INFO - Predictions for AVY made successfully.
# 2025-04-27 11:21:20,748 - inference - INFO - Predictions for AXON made successfully.
# 2025-04-27 11:21:20,825 - inference - INFO - Predictions for BKR made successfully.
# 2025-04-27 11:21:20,907 - inference - INFO - Predictions for BALL made successfully.
# 2025-04-27 11:21:20,984 - inference - INFO - Predictions for BAC made successfully.
# 2025-04-27 11:21:21,067 - inference - INFO - Predictions for BK made successfully.
# 2025-04-27 11:21:21,157 - inference - INFO - Predictions for BBWI made successfully.
# 2025-04-27 11:21:21,235 - inference - INFO - Predictions for BAX made successfully.
# 2025-04-27 11:21:21,317 - inference - INFO - Predictions for BDX made successfully.
# 2025-04-27 11:21:21,393 - inference - INFO - Predictions for BBY made successfully.
# 2025-04-27 11:21:21,463 - inference - INFO - Predictions for BIO made successfully.
# 2025-04-27 11:21:21,546 - inference - INFO - Predictions for TECH made successfully.
# 2025-04-27 11:21:21,624 - inference - INFO - Predictions for BIIB made successfully.
# 2025-04-27 11:21:21,697 - inference - INFO - Predictions for BLK made successfully.
# 2025-04-27 11:21:21,784 - inference - INFO - Predictions for BX made successfully.
# 2025-04-27 11:21:21,858 - inference - INFO - Predictions for BA made successfully.
# 2025-04-27 11:21:21,942 - inference - INFO - Predictions for BKNG made successfully.
# 2025-04-27 11:21:22,023 - inference - INFO - Predictions for BWA made successfully.
# 2025-04-27 11:21:22,105 - inference - INFO - Predictions for BXP made successfully.
# 2025-04-27 11:21:22,182 - inference - INFO - Predictions for BSX made successfully.
# 2025-04-27 11:21:22,258 - inference - INFO - Predictions for BMY made successfully.
# 2025-04-27 11:21:22,337 - inference - INFO - Predictions for AVGO made successfully.
# 2025-04-27 11:21:22,409 - inference - INFO - Predictions for BR made successfully.
# 2025-04-27 11:21:22,492 - inference - INFO - Predictions for BRO made successfully.
# 2025-04-27 11:21:22,572 - inference - INFO - Predictions for BLDR made successfully.
# 2025-04-27 11:21:22,649 - inference - INFO - Predictions for BG made successfully.
# 2025-04-27 11:21:22,734 - inference - INFO - Predictions for CDNS made successfully.
# 2025-04-27 11:21:22,815 - inference - INFO - Predictions for CPT made successfully.
# 2025-04-27 11:21:22,892 - inference - INFO - Predictions for CPB made successfully.
# 2025-04-27 11:21:22,973 - inference - INFO - Predictions for COF made successfully.
# 2025-04-27 11:21:23,046 - inference - INFO - Predictions for CAH made successfully.
# 2025-04-27 11:21:23,118 - inference - INFO - Predictions for KMX made successfully.
# 2025-04-27 11:21:23,196 - inference - INFO - Predictions for CCL made successfully.
# 2025-04-27 11:21:23,277 - inference - INFO - Predictions for CAT made successfully.
# 2025-04-27 11:21:23,367 - inference - INFO - Predictions for CBOE made successfully.
# 2025-04-27 11:21:23,439 - inference - INFO - Predictions for CBRE made successfully.
# 2025-04-27 11:21:23,534 - inference - INFO - Predictions for CDW made successfully.
# 2025-04-27 11:21:23,610 - inference - INFO - Predictions for CE made successfully.
# 2025-04-27 11:21:23,685 - inference - INFO - Predictions for COR made successfully.
# 2025-04-27 11:21:23,762 - inference - INFO - Predictions for CNC made successfully.
# 2025-04-27 11:21:23,839 - inference - INFO - Predictions for CNP made successfully.
# 2025-04-27 11:21:23,918 - inference - INFO - Predictions for CF made successfully.
# 2025-04-27 11:21:23,998 - inference - INFO - Predictions for CHRW made successfully.
# 2025-04-27 11:21:24,081 - inference - INFO - Predictions for CRL made successfully.
# 2025-04-27 11:21:24,160 - inference - INFO - Predictions for SCHW made successfully.
# 2025-04-27 11:21:24,372 - inference - INFO - Predictions for CHTR made successfully.
# 2025-04-27 11:21:24,449 - inference - INFO - Predictions for CVX made successfully.
# 2025-04-27 11:21:24,530 - inference - INFO - Predictions for CMG made successfully.
# 2025-04-27 11:21:24,615 - inference - INFO - Predictions for CB made successfully.
# 2025-04-27 11:21:24,692 - inference - INFO - Predictions for CHD made successfully.
# 2025-04-27 11:21:24,770 - inference - INFO - Predictions for CI made successfully.
# 2025-04-27 11:21:24,849 - inference - INFO - Predictions for CINF made successfully.
# 2025-04-27 11:21:24,922 - inference - INFO - Predictions for CTAS made successfully.
# 2025-04-27 11:21:25,002 - inference - INFO - Predictions for CSCO made successfully.
# 2025-04-27 11:21:25,077 - inference - INFO - Predictions for C made successfully.
# 2025-04-27 11:21:25,151 - inference - INFO - Predictions for CLX made successfully.
# 2025-04-27 11:21:25,228 - inference - INFO - Predictions for CME made successfully.
# 2025-04-27 11:21:25,306 - inference - INFO - Predictions for CMS made successfully.
# 2025-04-27 11:21:25,391 - inference - INFO - Predictions for KO made successfully.
# 2025-04-27 11:21:25,475 - inference - INFO - Predictions for CTSH made successfully.
# 2025-04-27 11:21:25,552 - inference - INFO - Predictions for CL made successfully.
# 2025-04-27 11:21:25,623 - inference - INFO - Predictions for CMCSA made successfully.
# 2025-04-27 11:21:25,702 - inference - INFO - Predictions for CMA made successfully.
# 2025-04-27 11:21:25,779 - inference - INFO - Predictions for CAG made successfully.
# 2025-04-27 11:21:25,857 - inference - INFO - Predictions for COP made successfully.
# 2025-04-27 11:21:25,940 - inference - INFO - Predictions for ED made successfully.
# 2025-04-27 11:21:26,016 - inference - INFO - Predictions for STZ made successfully.
# 2025-04-27 11:21:26,098 - inference - INFO - Predictions for COO made successfully.
# 2025-04-27 11:21:26,183 - inference - INFO - Predictions for CPRT made successfully.
# 2025-04-27 11:21:26,260 - inference - INFO - Predictions for GLW made successfully.
# 2025-04-27 11:21:26,344 - inference - INFO - Predictions for CPAY made successfully.
# 2025-04-27 11:21:26,420 - inference - INFO - Predictions for CSGP made successfully.
# 2025-04-27 11:21:26,497 - inference - INFO - Predictions for COST made successfully.
# 2025-04-27 11:21:26,575 - inference - INFO - Predictions for CTRA made successfully.
# 2025-04-27 11:21:26,654 - inference - INFO - Predictions for CCI made successfully.
# 2025-04-27 11:21:26,731 - inference - INFO - Predictions for CSX made successfully.
# 2025-04-27 11:21:26,813 - inference - INFO - Predictions for CMI made successfully.
# 2025-04-27 11:21:26,886 - inference - INFO - Predictions for CVS made successfully.
# 2025-04-27 11:21:26,968 - inference - INFO - Predictions for DHR made successfully.
# 2025-04-27 11:21:27,047 - inference - INFO - Predictions for DRI made successfully.
# 2025-04-27 11:21:27,130 - inference - INFO - Predictions for DVA made successfully.
# 2025-04-27 11:21:27,208 - inference - INFO - Predictions for DECK made successfully.
# 2025-04-27 11:21:27,284 - inference - INFO - Predictions for DE made successfully.
# 2025-04-27 11:21:27,367 - inference - INFO - Predictions for DAL made successfully.
# 2025-04-27 11:21:27,449 - inference - INFO - Predictions for DVN made successfully.
# 2025-04-27 11:21:27,528 - inference - INFO - Predictions for DXCM made successfully.
# 2025-04-27 11:21:27,607 - inference - INFO - Predictions for FANG made successfully.
# 2025-04-27 11:21:27,683 - inference - INFO - Predictions for DLR made successfully.
# 2025-04-27 11:21:27,762 - inference - INFO - Predictions for DFS made successfully.
# 2025-04-27 11:21:27,838 - inference - INFO - Predictions for DG made successfully.
# 2025-04-27 11:21:27,920 - inference - INFO - Predictions for DLTR made successfully.
# 2025-04-27 11:21:27,998 - inference - INFO - Predictions for D made successfully.
# 2025-04-27 11:21:28,072 - inference - INFO - Predictions for DPZ made successfully.
# 2025-04-27 11:21:28,152 - inference - INFO - Predictions for DOV made successfully.
# 2025-04-27 11:21:28,240 - inference - INFO - Predictions for DHI made successfully.
# 2025-04-27 11:21:28,324 - inference - INFO - Predictions for DTE made successfully.
# 2025-04-27 11:21:28,408 - inference - INFO - Predictions for DUK made successfully.
# 2025-04-27 11:21:28,478 - inference - INFO - Predictions for DD made successfully.
# 2025-04-27 11:21:28,556 - inference - INFO - Predictions for EMN made successfully.
# 2025-04-27 11:21:28,636 - inference - INFO - Predictions for ETN made successfully.
# 2025-04-27 11:21:28,713 - inference - INFO - Predictions for EBAY made successfully.
# 2025-04-27 11:21:28,787 - inference - INFO - Predictions for ECL made successfully.
# 2025-04-27 11:21:28,864 - inference - INFO - Predictions for EIX made successfully.
# 2025-04-27 11:21:28,946 - inference - INFO - Predictions for EW made successfully.
# 2025-04-27 11:21:29,020 - inference - INFO - Predictions for EA made successfully.
# 2025-04-27 11:21:29,099 - inference - INFO - Predictions for ELV made successfully.
# 2025-04-27 11:21:29,180 - inference - INFO - Predictions for LLY made successfully.
# 2025-04-27 11:21:29,266 - inference - INFO - Predictions for EMR made successfully.
# 2025-04-27 11:21:29,338 - inference - INFO - Predictions for ENPH made successfully.
# 2025-04-27 11:21:29,416 - inference - INFO - Predictions for ETR made successfully.
# 2025-04-27 11:21:29,493 - inference - INFO - Predictions for EOG made successfully.
# 2025-04-27 11:21:29,571 - inference - INFO - Predictions for EPAM made successfully.
# 2025-04-27 11:21:29,649 - inference - INFO - Predictions for EQT made successfully.
# 2025-04-27 11:21:29,719 - inference - INFO - Predictions for EFX made successfully.
# 2025-04-27 11:21:29,793 - inference - INFO - Predictions for EQIX made successfully.
# 2025-04-27 11:21:29,872 - inference - INFO - Predictions for EQR made successfully.
# 2025-04-27 11:21:29,955 - inference - INFO - Predictions for ESS made successfully.
# 2025-04-27 11:21:30,031 - inference - INFO - Predictions for EL made successfully.
# 2025-04-27 11:21:30,109 - inference - INFO - Predictions for EG made successfully.
# 2025-04-27 11:21:30,197 - inference - INFO - Predictions for EVRG made successfully.
# 2025-04-27 11:21:30,278 - inference - INFO - Predictions for ES made successfully.
# 2025-04-27 11:21:30,353 - inference - INFO - Predictions for EXC made successfully.
# 2025-04-27 11:21:30,425 - inference - INFO - Predictions for EXPE made successfully.
# 2025-04-27 11:21:30,511 - inference - INFO - Predictions for EXPD made successfully.
# 2025-04-27 11:21:30,581 - inference - INFO - Predictions for EXR made successfully.
# 2025-04-27 11:21:30,651 - inference - INFO - Predictions for XOM made successfully.
# 2025-04-27 11:21:30,736 - inference - INFO - Predictions for FFIV made successfully.
# 2025-04-27 11:21:30,816 - inference - INFO - Predictions for FDS made successfully.
# 2025-04-27 11:21:30,890 - inference - INFO - Predictions for FICO made successfully.
# 2025-04-27 11:21:30,970 - inference - INFO - Predictions for FAST made successfully.
# 2025-04-27 11:21:31,058 - inference - INFO - Predictions for FRT made successfully.
# 2025-04-27 11:21:31,139 - inference - INFO - Predictions for FDX made successfully.
# 2025-04-27 11:21:31,233 - inference - INFO - Predictions for FIS made successfully.
# 2025-04-27 11:21:31,309 - inference - INFO - Predictions for FITB made successfully.
# 2025-04-27 11:21:31,388 - inference - INFO - Predictions for FSLR made successfully.
# 2025-04-27 11:21:31,466 - inference - INFO - Predictions for FE made successfully.
# 2025-04-27 11:21:31,545 - inference - INFO - Predictions for FI made successfully.
# 2025-04-27 11:21:31,622 - inference - INFO - Predictions for FMC made successfully.
# 2025-04-27 11:21:31,700 - inference - INFO - Predictions for F made successfully.
# 2025-04-27 11:21:31,781 - inference - INFO - Predictions for FTNT made successfully.
# 2025-04-27 11:21:31,856 - inference - INFO - Predictions for BEN made successfully.
# 2025-04-27 11:21:31,934 - inference - INFO - Predictions for FCX made successfully.
# 2025-04-27 11:21:32,006 - inference - INFO - Predictions for GRMN made successfully.
# 2025-04-27 11:21:32,083 - inference - INFO - Predictions for IT made successfully.
# 2025-04-27 11:21:32,158 - inference - INFO - Predictions for GE made successfully.
# 2025-04-27 11:21:32,237 - inference - INFO - Predictions for GEN made successfully.
# 2025-04-27 11:21:32,317 - inference - INFO - Predictions for GNRC made successfully.
# 2025-04-27 11:21:32,393 - inference - INFO - Predictions for GD made successfully.
# 2025-04-27 11:21:32,472 - inference - INFO - Predictions for GIS made successfully.
# 2025-04-27 11:21:32,558 - inference - INFO - Predictions for GM made successfully.
# 2025-04-27 11:21:32,636 - inference - INFO - Predictions for GPC made successfully.
# 2025-04-27 11:21:32,711 - inference - INFO - Predictions for GILD made successfully.
# 2025-04-27 11:21:32,787 - inference - INFO - Predictions for GPN made successfully.
# 2025-04-27 11:21:32,865 - inference - INFO - Predictions for GL made successfully.
# 2025-04-27 11:21:32,939 - inference - INFO - Predictions for GS made successfully.
# 2025-04-27 11:21:33,019 - inference - INFO - Predictions for HAL made successfully.
# 2025-04-27 11:21:33,108 - inference - INFO - Predictions for HIG made successfully.
# 2025-04-27 11:21:33,187 - inference - INFO - Predictions for HAS made successfully.
# 2025-04-27 11:21:33,257 - inference - INFO - Predictions for HCA made successfully.
# 2025-04-27 11:21:33,333 - inference - INFO - Predictions for DOC made successfully.
# 2025-04-27 11:21:33,419 - inference - INFO - Predictions for HSIC made successfully.
# 2025-04-27 11:21:33,501 - inference - INFO - Predictions for HSY made successfully.
# 2025-04-27 11:21:33,577 - inference - INFO - Predictions for HES made successfully.
# 2025-04-27 11:21:33,653 - inference - INFO - Predictions for HLT made successfully.
# 2025-04-27 11:21:33,733 - inference - INFO - Predictions for HOLX made successfully.
# 2025-04-27 11:21:33,813 - inference - INFO - Predictions for HD made successfully.
# 2025-04-27 11:21:33,888 - inference - INFO - Predictions for HON made successfully.
# 2025-04-27 11:21:33,962 - inference - INFO - Predictions for HRL made successfully.
# 2025-04-27 11:21:34,040 - inference - INFO - Predictions for HST made successfully.
# 2025-04-27 11:21:34,113 - inference - INFO - Predictions for HPQ made successfully.
# 2025-04-27 11:21:34,190 - inference - INFO - Predictions for HUBB made successfully.
# 2025-04-27 11:21:34,270 - inference - INFO - Predictions for HUM made successfully.
# 2025-04-27 11:21:34,349 - inference - INFO - Predictions for HBAN made successfully.
# 2025-04-27 11:21:34,424 - inference - INFO - Predictions for HII made successfully.
# 2025-04-27 11:21:34,508 - inference - INFO - Predictions for IBM made successfully.
# 2025-04-27 11:21:34,615 - inference - INFO - Predictions for IEX made successfully.
# 2025-04-27 11:21:34,690 - inference - INFO - Predictions for IDXX made successfully.
# 2025-04-27 11:21:34,766 - inference - INFO - Predictions for ITW made successfully.
# 2025-04-27 11:21:34,842 - inference - INFO - Predictions for ILMN made successfully.
# 2025-04-27 11:21:34,920 - inference - INFO - Predictions for INCY made successfully.
# 2025-04-27 11:21:34,997 - inference - INFO - Predictions for PODD made successfully.
# 2025-04-27 11:21:35,073 - inference - INFO - Predictions for INTC made successfully.
# 2025-04-27 11:21:35,166 - inference - INFO - Predictions for ICE made successfully.
# 2025-04-27 11:21:35,244 - inference - INFO - Predictions for IFF made successfully.
# 2025-04-27 11:21:35,322 - inference - INFO - Predictions for IP made successfully.
# 2025-04-27 11:21:35,407 - inference - INFO - Predictions for IPG made successfully.
# 2025-04-27 11:21:35,485 - inference - INFO - Predictions for INTU made successfully.
# 2025-04-27 11:21:35,561 - inference - INFO - Predictions for ISRG made successfully.
# 2025-04-27 11:21:35,638 - inference - INFO - Predictions for IVZ made successfully.
# 2025-04-27 11:21:35,718 - inference - INFO - Predictions for IQV made successfully.
# 2025-04-27 11:21:35,799 - inference - INFO - Predictions for IRM made successfully.
# 2025-04-27 11:21:35,876 - inference - INFO - Predictions for JBHT made successfully.
# 2025-04-27 11:21:35,951 - inference - INFO - Predictions for JBL made successfully.
# 2025-04-27 11:21:36,027 - inference - INFO - Predictions for JKHY made successfully.
# 2025-04-27 11:21:36,106 - inference - INFO - Predictions for J made successfully.
# 2025-04-27 11:21:36,180 - inference - INFO - Predictions for JNJ made successfully.
# 2025-04-27 11:21:36,256 - inference - INFO - Predictions for JCI made successfully.
# 2025-04-27 11:21:36,334 - inference - INFO - Predictions for JPM made successfully.
# 2025-04-27 11:21:36,413 - inference - INFO - Predictions for JNPR made successfully.
# 2025-04-27 11:21:36,489 - inference - INFO - Predictions for K made successfully.
# 2025-04-27 11:21:36,571 - inference - INFO - Predictions for KDP made successfully.
# 2025-04-27 11:21:36,649 - inference - INFO - Predictions for KEY made successfully.
# 2025-04-27 11:21:36,721 - inference - INFO - Predictions for KMB made successfully.
# 2025-04-27 11:21:36,805 - inference - INFO - Predictions for KIM made successfully.
# 2025-04-27 11:21:36,884 - inference - INFO - Predictions for KMI made successfully.
# 2025-04-27 11:21:36,958 - inference - INFO - Predictions for KLAC made successfully.
# 2025-04-27 11:21:37,037 - inference - INFO - Predictions for KR made successfully.
# 2025-04-27 11:21:37,114 - inference - INFO - Predictions for LHX made successfully.
# 2025-04-27 11:21:37,192 - inference - INFO - Predictions for LH made successfully.
# 2025-04-27 11:21:37,267 - inference - INFO - Predictions for LRCX made successfully.
# 2025-04-27 11:21:37,346 - inference - INFO - Predictions for LVS made successfully.
# 2025-04-27 11:21:37,431 - inference - INFO - Predictions for LDOS made successfully.
# 2025-04-27 11:21:37,512 - inference - INFO - Predictions for LEN made successfully.
# 2025-04-27 11:21:37,589 - inference - INFO - Predictions for LIN made successfully.
# 2025-04-27 11:21:37,673 - inference - INFO - Predictions for LYV made successfully.
# 2025-04-27 11:21:37,755 - inference - INFO - Predictions for LKQ made successfully.
# 2025-04-27 11:21:37,838 - inference - INFO - Predictions for LMT made successfully.
# 2025-04-27 11:21:37,914 - inference - INFO - Predictions for L made successfully.
# 2025-04-27 11:21:37,991 - inference - INFO - Predictions for LOW made successfully.
# 2025-04-27 11:21:38,074 - inference - INFO - Predictions for LULU made successfully.
# 2025-04-27 11:21:38,154 - inference - INFO - Predictions for LYB made successfully.
# 2025-04-27 11:21:38,230 - inference - INFO - Predictions for MTB made successfully.
# 2025-04-27 11:21:38,312 - inference - INFO - Predictions for MRO made successfully.
# 2025-04-27 11:21:38,390 - inference - INFO - Predictions for MPC made successfully.
# 2025-04-27 11:21:38,466 - inference - INFO - Predictions for MKTX made successfully.
# 2025-04-27 11:21:38,543 - inference - INFO - Predictions for MAR made successfully.
# 2025-04-27 11:21:38,624 - inference - INFO - Predictions for MMC made successfully.
# 2025-04-27 11:21:38,701 - inference - INFO - Predictions for MLM made successfully.
# 2025-04-27 11:21:38,788 - inference - INFO - Predictions for MAS made successfully.
# 2025-04-27 11:21:38,869 - inference - INFO - Predictions for MA made successfully.
# 2025-04-27 11:21:38,944 - inference - INFO - Predictions for MTCH made successfully.
# 2025-04-27 11:21:39,023 - inference - INFO - Predictions for MKC made successfully.
# 2025-04-27 11:21:39,105 - inference - INFO - Predictions for MCD made successfully.
# 2025-04-27 11:21:39,185 - inference - INFO - Predictions for MCK made successfully.
# 2025-04-27 11:21:39,266 - inference - INFO - Predictions for MDT made successfully.
# 2025-04-27 11:21:39,345 - inference - INFO - Predictions for MRK made successfully.
# 2025-04-27 11:21:39,425 - inference - INFO - Predictions for META made successfully.
# 2025-04-27 11:21:39,498 - inference - INFO - Predictions for MET made successfully.
# 2025-04-27 11:21:39,579 - inference - INFO - Predictions for MTD made successfully.
# 2025-04-27 11:21:39,659 - inference - INFO - Predictions for MGM made successfully.
# 2025-04-27 11:21:39,733 - inference - INFO - Predictions for MCHP made successfully.
# 2025-04-27 11:21:39,813 - inference - INFO - Predictions for MU made successfully.
# 2025-04-27 11:21:39,894 - inference - INFO - Predictions for MSFT made successfully.
# 2025-04-27 11:21:39,972 - inference - INFO - Predictions for MAA made successfully.
# 2025-04-27 11:21:40,053 - inference - INFO - Predictions for MHK made successfully.
# 2025-04-27 11:21:40,130 - inference - INFO - Predictions for MOH made successfully.
# 2025-04-27 11:21:40,211 - inference - INFO - Predictions for TAP made successfully.
# 2025-04-27 11:21:40,296 - inference - INFO - Predictions for MDLZ made successfully.
# 2025-04-27 11:21:40,373 - inference - INFO - Predictions for MPWR made successfully.
# 2025-04-27 11:21:40,448 - inference - INFO - Predictions for MNST made successfully.
# 2025-04-27 11:21:40,527 - inference - INFO - Predictions for MCO made successfully.
# 2025-04-27 11:21:40,602 - inference - INFO - Predictions for MS made successfully.
# 2025-04-27 11:21:40,680 - inference - INFO - Predictions for MOS made successfully.
# 2025-04-27 11:21:40,753 - inference - INFO - Predictions for MSI made successfully.
# 2025-04-27 11:21:40,827 - inference - INFO - Predictions for MSCI made successfully.
# 2025-04-27 11:21:40,919 - inference - INFO - Predictions for NDAQ made successfully.
# 2025-04-27 11:21:40,996 - inference - INFO - Predictions for NTAP made successfully.
# 2025-04-27 11:21:41,072 - inference - INFO - Predictions for NFLX made successfully.
# 2025-04-27 11:21:41,148 - inference - INFO - Predictions for NEM made successfully.
# 2025-04-27 11:21:41,224 - inference - INFO - Predictions for NWSA made successfully.
# 2025-04-27 11:21:41,307 - inference - INFO - Predictions for NWS made successfully.
# 2025-04-27 11:21:41,384 - inference - INFO - Predictions for NEE made successfully.
# 2025-04-27 11:21:41,497 - inference - INFO - Predictions for NKE made successfully.
# 2025-04-27 11:21:41,575 - inference - INFO - Predictions for NI made successfully.
# 2025-04-27 11:21:41,650 - inference - INFO - Predictions for NDSN made successfully.
# 2025-04-27 11:21:41,722 - inference - INFO - Predictions for NSC made successfully.
# 2025-04-27 11:21:41,794 - inference - INFO - Predictions for NTRS made successfully.
# 2025-04-27 11:21:41,876 - inference - INFO - Predictions for NOC made successfully.
# 2025-04-27 11:21:41,961 - inference - INFO - Predictions for NCLH made successfully.
# 2025-04-27 11:21:42,045 - inference - INFO - Predictions for NRG made successfully.
# 2025-04-27 11:21:42,122 - inference - INFO - Predictions for NUE made successfully.
# 2025-04-27 11:21:42,203 - inference - INFO - Predictions for NVDA made successfully.
# 2025-04-27 11:21:42,280 - inference - INFO - Predictions for NVR made successfully.
# 2025-04-27 11:21:42,355 - inference - INFO - Predictions for NXPI made successfully.
# 2025-04-27 11:21:42,433 - inference - INFO - Predictions for ORLY made successfully.
# 2025-04-27 11:21:42,509 - inference - INFO - Predictions for OXY made successfully.
# 2025-04-27 11:21:42,585 - inference - INFO - Predictions for ODFL made successfully.
# 2025-04-27 11:21:42,663 - inference - INFO - Predictions for OMC made successfully.
# 2025-04-27 11:21:42,735 - inference - INFO - Predictions for ON made successfully.
# 2025-04-27 11:21:42,817 - inference - INFO - Predictions for OKE made successfully.
# 2025-04-27 11:21:42,894 - inference - INFO - Predictions for ORCL made successfully.
# 2025-04-27 11:21:42,976 - inference - INFO - Predictions for PCAR made successfully.
# 2025-04-27 11:21:43,063 - inference - INFO - Predictions for PKG made successfully.
# 2025-04-27 11:21:43,143 - inference - INFO - Predictions for PANW made successfully.
# 2025-04-27 11:21:43,224 - inference - INFO - Predictions for PARA made successfully.
# 2025-04-27 11:21:43,303 - inference - INFO - Predictions for PH made successfully.
# 2025-04-27 11:21:43,378 - inference - INFO - Predictions for PAYX made successfully.
# 2025-04-27 11:21:43,460 - inference - INFO - Predictions for PNR made successfully.
# 2025-04-27 11:21:43,545 - inference - INFO - Predictions for PEP made successfully.
# 2025-04-27 11:21:43,623 - inference - INFO - Predictions for PFE made successfully.
# 2025-04-27 11:21:43,699 - inference - INFO - Predictions for PCG made successfully.
# 2025-04-27 11:21:43,782 - inference - INFO - Predictions for PM made successfully.
# 2025-04-27 11:21:43,866 - inference - INFO - Predictions for PSX made successfully.
# 2025-04-27 11:21:43,946 - inference - INFO - Predictions for PNW made successfully.
# 2025-04-27 11:21:44,028 - inference - INFO - Predictions for PXD made successfully.
# 2025-04-27 11:21:44,109 - inference - INFO - Predictions for PNC made successfully.
# 2025-04-27 11:21:44,188 - inference - INFO - Predictions for POOL made successfully.
# 2025-04-27 11:21:44,264 - inference - INFO - Predictions for PPG made successfully.
# 2025-04-27 11:21:44,342 - inference - INFO - Predictions for PPL made successfully.
# 2025-04-27 11:21:44,423 - inference - INFO - Predictions for PFG made successfully.
# 2025-04-27 11:21:44,509 - inference - INFO - Predictions for PG made successfully.
# 2025-04-27 11:21:44,587 - inference - INFO - Predictions for PGR made successfully.
# 2025-04-27 11:21:44,671 - inference - INFO - Predictions for PLD made successfully.
# 2025-04-27 11:21:44,752 - inference - INFO - Predictions for PRU made successfully.
# 2025-04-27 11:21:44,835 - inference - INFO - Predictions for PEG made successfully.
# 2025-04-27 11:21:44,910 - inference - INFO - Predictions for PTC made successfully.
# 2025-04-27 11:21:44,989 - inference - INFO - Predictions for PSA made successfully.
# 2025-04-27 11:21:45,068 - inference - INFO - Predictions for PHM made successfully.
# 2025-04-27 11:21:45,147 - inference - INFO - Predictions for PWR made successfully.
# 2025-04-27 11:21:45,235 - inference - INFO - Predictions for QCOM made successfully.
# 2025-04-27 11:21:45,310 - inference - INFO - Predictions for DGX made successfully.
# 2025-04-27 11:21:45,389 - inference - INFO - Predictions for RL made successfully.
# 2025-04-27 11:21:45,468 - inference - INFO - Predictions for RJF made successfully.
# 2025-04-27 11:21:45,548 - inference - INFO - Predictions for RTX made successfully.
# 2025-04-27 11:21:45,618 - inference - INFO - Predictions for O made successfully.
# 2025-04-27 11:21:45,697 - inference - INFO - Predictions for REG made successfully.
# 2025-04-27 11:21:45,779 - inference - INFO - Predictions for REGN made successfully.
# 2025-04-27 11:21:45,867 - inference - INFO - Predictions for RF made successfully.
# 2025-04-27 11:21:45,946 - inference - INFO - Predictions for RSG made successfully.
# 2025-04-27 11:21:46,029 - inference - INFO - Predictions for RMD made successfully.
# 2025-04-27 11:21:46,104 - inference - INFO - Predictions for RVTY made successfully.
# 2025-04-27 11:21:46,181 - inference - INFO - Predictions for RHI made successfully.
# 2025-04-27 11:21:46,256 - inference - INFO - Predictions for ROK made successfully.
# 2025-04-27 11:21:46,332 - inference - INFO - Predictions for ROL made successfully.
# 2025-04-27 11:21:46,422 - inference - INFO - Predictions for ROP made successfully.
# 2025-04-27 11:21:46,509 - inference - INFO - Predictions for ROST made successfully.
# 2025-04-27 11:21:46,588 - inference - INFO - Predictions for RCL made successfully.
# 2025-04-27 11:21:46,671 - inference - INFO - Predictions for SPGI made successfully.
# 2025-04-27 11:21:46,750 - inference - INFO - Predictions for CRM made successfully.
# 2025-04-27 11:21:46,832 - inference - INFO - Predictions for SBAC made successfully.
# 2025-04-27 11:21:46,911 - inference - INFO - Predictions for SLB made successfully.
# 2025-04-27 11:21:46,988 - inference - INFO - Predictions for STX made successfully.
# 2025-04-27 11:21:47,064 - inference - INFO - Predictions for SRE made successfully.
# 2025-04-27 11:21:47,147 - inference - INFO - Predictions for NOW made successfully.
# 2025-04-27 11:21:47,227 - inference - INFO - Predictions for SHW made successfully.
# 2025-04-27 11:21:47,304 - inference - INFO - Predictions for SPG made successfully.
# 2025-04-27 11:21:47,387 - inference - INFO - Predictions for SWKS made successfully.
# 2025-04-27 11:21:47,465 - inference - INFO - Predictions for SJM made successfully.
# 2025-04-27 11:21:47,543 - inference - INFO - Predictions for SNA made successfully.
# 2025-04-27 11:21:47,625 - inference - INFO - Predictions for SO made successfully.
# 2025-04-27 11:21:47,699 - inference - INFO - Predictions for LUV made successfully.
# 2025-04-27 11:21:47,777 - inference - INFO - Predictions for SWK made successfully.
# 2025-04-27 11:21:47,863 - inference - INFO - Predictions for SBUX made successfully.
# 2025-04-27 11:21:47,942 - inference - INFO - Predictions for STT made successfully.
# 2025-04-27 11:21:48,017 - inference - INFO - Predictions for STLD made successfully.
# 2025-04-27 11:21:48,110 - inference - INFO - Predictions for STE made successfully.
# 2025-04-27 11:21:48,206 - inference - INFO - Predictions for SYK made successfully.
# 2025-04-27 11:21:48,291 - inference - INFO - Predictions for SMCI made successfully.
# 2025-04-27 11:21:48,374 - inference - INFO - Predictions for SNPS made successfully.
# 2025-04-27 11:21:48,455 - inference - INFO - Predictions for SYY made successfully.
# 2025-04-27 11:21:48,535 - inference - INFO - Predictions for TMUS made successfully.
# 2025-04-27 11:21:48,618 - inference - INFO - Predictions for TROW made successfully.
# 2025-04-27 11:21:48,690 - inference - INFO - Predictions for TTWO made successfully.
# 2025-04-27 11:21:48,761 - inference - INFO - Predictions for TPR made successfully.
# 2025-04-27 11:21:48,841 - inference - INFO - Predictions for TRGP made successfully.
# 2025-04-27 11:21:48,921 - inference - INFO - Predictions for TGT made successfully.
# 2025-04-27 11:21:49,006 - inference - INFO - Predictions for TEL made successfully.
# 2025-04-27 11:21:49,084 - inference - INFO - Predictions for TDY made successfully.
# 2025-04-27 11:21:49,157 - inference - INFO - Predictions for TFX made successfully.
# 2025-04-27 11:21:49,243 - inference - INFO - Predictions for TER made successfully.
# 2025-04-27 11:21:49,325 - inference - INFO - Predictions for TSLA made successfully.
# 2025-04-27 11:21:49,403 - inference - INFO - Predictions for TXN made successfully.
# 2025-04-27 11:21:49,483 - inference - INFO - Predictions for TXT made successfully.
# 2025-04-27 11:21:49,566 - inference - INFO - Predictions for TMO made successfully.
# 2025-04-27 11:21:49,849 - inference - INFO - Predictions for TJX made successfully.
# 2025-04-27 11:21:49,935 - inference - INFO - Predictions for TSCO made successfully.
# 2025-04-27 11:21:50,012 - inference - INFO - Predictions for TT made successfully.
# 2025-04-27 11:21:50,083 - inference - INFO - Predictions for TDG made successfully.
# 2025-04-27 11:21:50,182 - inference - INFO - Predictions for TRV made successfully.
# 2025-04-27 11:21:50,264 - inference - INFO - Predictions for TRMB made successfully.
# 2025-04-27 11:21:50,339 - inference - INFO - Predictions for TFC made successfully.
# 2025-04-27 11:21:50,420 - inference - INFO - Predictions for TYL made successfully.
# 2025-04-27 11:21:50,498 - inference - INFO - Predictions for TSN made successfully.
# 2025-04-27 11:21:50,576 - inference - INFO - Predictions for USB made successfully.
# 2025-04-27 11:21:50,653 - inference - INFO - Predictions for UDR made successfully.
# 2025-04-27 11:21:50,731 - inference - INFO - Predictions for ULTA made successfully.
# 2025-04-27 11:21:50,812 - inference - INFO - Predictions for UNP made successfully.
# 2025-04-27 11:21:50,894 - inference - INFO - Predictions for UAL made successfully.
# 2025-04-27 11:21:50,967 - inference - INFO - Predictions for UPS made successfully.
# 2025-04-27 11:21:51,048 - inference - INFO - Predictions for URI made successfully.
# 2025-04-27 11:21:51,129 - inference - INFO - Predictions for UNH made successfully.
# 2025-04-27 11:21:51,203 - inference - INFO - Predictions for UHS made successfully.
# 2025-04-27 11:21:51,309 - inference - INFO - Predictions for VLO made successfully.
# 2025-04-27 11:21:51,398 - inference - INFO - Predictions for VTR made successfully.
# 2025-04-27 11:21:51,479 - inference - INFO - Predictions for VRSN made successfully.
# 2025-04-27 11:21:51,556 - inference - INFO - Predictions for VRSK made successfully.
# 2025-04-27 11:21:51,636 - inference - INFO - Predictions for VZ made successfully.
# 2025-04-27 11:21:51,707 - inference - INFO - Predictions for VRTX made successfully.
# 2025-04-27 11:21:51,793 - inference - INFO - Predictions for VTRS made successfully.
# 2025-04-27 11:21:51,868 - inference - INFO - Predictions for V made successfully.
# 2025-04-27 11:21:51,947 - inference - INFO - Predictions for VMC made successfully.
# 2025-04-27 11:21:52,025 - inference - INFO - Predictions for WRB made successfully.
# 2025-04-27 11:21:52,099 - inference - INFO - Predictions for WAB made successfully.
# 2025-04-27 11:21:52,169 - inference - INFO - Predictions for WBA made successfully.
# 2025-04-27 11:21:52,246 - inference - INFO - Predictions for WMT made successfully.
# 2025-04-27 11:21:52,325 - inference - INFO - Predictions for DIS made successfully.
# 2025-04-27 11:21:52,407 - inference - INFO - Predictions for WBD made successfully.
# 2025-04-27 11:21:52,488 - inference - INFO - Predictions for WM made successfully.
# 2025-04-27 11:21:52,563 - inference - INFO - Predictions for WAT made successfully.
# 2025-04-27 11:21:52,635 - inference - INFO - Predictions for WEC made successfully.
# 2025-04-27 11:21:52,925 - inference - INFO - Predictions for WFC made successfully.
# 2025-04-27 11:21:53,005 - inference - INFO - Predictions for WELL made successfully.
# 2025-04-27 11:21:53,085 - inference - INFO - Predictions for WST made successfully.
# 2025-04-27 11:21:53,176 - inference - INFO - Predictions for WDC made successfully.
# 2025-04-27 11:21:53,257 - inference - INFO - Predictions for WY made successfully.
# 2025-04-27 11:21:53,334 - inference - INFO - Predictions for WMB made successfully.
# 2025-04-27 11:21:53,420 - inference - INFO - Predictions for WTW made successfully.
# 2025-04-27 11:21:53,500 - inference - INFO - Predictions for GWW made successfully.
# 2025-04-27 11:21:53,579 - inference - INFO - Predictions for WYNN made successfully.
# 2025-04-27 11:21:53,665 - inference - INFO - Predictions for XEL made successfully.
# 2025-04-27 11:21:53,750 - inference - INFO - Predictions for XYL made successfully.
# 2025-04-27 11:21:53,823 - inference - INFO - Predictions for YUM made successfully.
# 2025-04-27 11:21:53,908 - inference - INFO - Predictions for ZBRA made successfully.
# 2025-04-27 11:21:53,982 - inference - INFO - Predictions for ZBH made successfully.
# 2025-04-27 11:21:54,063 - inference - INFO - Predictions for ZTS made successfully.
# 2025-04-27 11:21:54,143 - inference - INFO - Predictions for ABB.ST made successfully.
# 2025-04-27 11:21:54,221 - inference - INFO - Predictions for ALFA.ST made successfully.
# 2025-04-27 11:21:54,300 - inference - INFO - Predictions for ASSA-B.ST made successfully.
# 2025-04-27 11:21:54,380 - inference - INFO - Predictions for AZN.ST made successfully.
# 2025-04-27 11:21:54,455 - inference - INFO - Predictions for ATCO-A.ST made successfully.
# 2025-04-27 11:21:54,533 - inference - INFO - Predictions for ATCO-B.ST made successfully.
# 2025-04-27 11:21:54,612 - inference - INFO - Predictions for ALIV-SDB.ST made successfully.
# 2025-04-27 11:21:54,687 - inference - INFO - Predictions for BOL.ST made successfully.
# 2025-04-27 11:21:54,770 - inference - INFO - Predictions for ELUX-B.ST made successfully.
# 2025-04-27 11:21:54,848 - inference - INFO - Predictions for ERIC-B.ST made successfully.
# 2025-04-27 11:21:54,927 - inference - INFO - Predictions for GETI-B.ST made successfully.
# 2025-04-27 11:21:55,005 - inference - INFO - Predictions for HM-B.ST made successfully.
# 2025-04-27 11:21:55,078 - inference - INFO - Predictions for HEXA-B.ST made successfully.
# 2025-04-27 11:21:55,160 - inference - INFO - Predictions for INVE-B.ST made successfully.
# 2025-04-27 11:21:55,243 - inference - INFO - Predictions for KINV-B.ST made successfully.
# 2025-04-27 11:21:55,329 - inference - INFO - Predictions for NDA-SE.ST made successfully.
# 2025-04-27 11:21:55,406 - inference - INFO - Predictions for SAND.ST made successfully.
# 2025-04-27 11:21:55,489 - inference - INFO - Predictions for SEB-A.ST made successfully.
# 2025-04-27 11:21:55,567 - inference - INFO - Predictions for SKA-B.ST made successfully.
# 2025-04-27 11:21:55,642 - inference - INFO - Predictions for SKF-B.ST made successfully.
# 2025-04-27 11:21:55,718 - inference - INFO - Predictions for SCA-B.ST made successfully.
# 2025-04-27 11:21:55,789 - inference - INFO - Predictions for SHB-A.ST made successfully.
# 2025-04-27 11:21:55,867 - inference - INFO - Predictions for SWED-A.ST made successfully.
# 2025-04-27 11:21:55,959 - inference - INFO - Predictions for TEL2-B.ST made successfully.
# 2025-04-27 11:21:56,035 - inference - INFO - Predictions for TELIA.ST made successfully.
# 2025-04-27 11:21:56,107 - inference - INFO - Predictions for VOLV-B.ST made successfully.
# 2025-04-27 11:21:56,179 - inference - INFO - Predictions for AI.PA made successfully.
# 2025-04-27 11:21:56,251 - inference - INFO - Predictions for AIR.PA made successfully.
# 2025-04-27 11:21:56,330 - inference - INFO - Predictions for ALO.PA made successfully.
# 2025-04-27 11:21:56,409 - inference - INFO - Predictions for MT.AS made successfully.
# 2025-04-27 11:21:56,483 - inference - INFO - Predictions for CS.PA made successfully.
# 2025-04-27 11:21:56,571 - inference - INFO - Predictions for BNP.PA made successfully.
# 2025-04-27 11:21:56,655 - inference - INFO - Predictions for EN.PA made successfully.
# 2025-04-27 11:21:56,731 - inference - INFO - Predictions for CAP.PA made successfully.
# 2025-04-27 11:21:56,818 - inference - INFO - Predictions for CA.PA made successfully.
# 2025-04-27 11:21:56,892 - inference - INFO - Predictions for ACA.PA made successfully.
# 2025-04-27 11:21:56,970 - inference - INFO - Predictions for BN.PA made successfully.
# 2025-04-27 11:21:57,050 - inference - INFO - Predictions for DSY.PA made successfully.
# 2025-04-27 11:21:57,123 - inference - INFO - Predictions for EDEN.PA made successfully.
# 2025-04-27 11:21:57,215 - inference - INFO - Predictions for ENGI.PA made successfully.
# 2025-04-27 11:21:57,291 - inference - INFO - Predictions for EL.PA made successfully.
# 2025-04-27 11:21:57,372 - inference - INFO - Predictions for ERF.PA made successfully.
# 2025-04-27 11:21:57,447 - inference - INFO - Predictions for RMS.PA made successfully.
# 2025-04-27 11:21:57,524 - inference - INFO - Predictions for KER.PA made successfully.
# 2025-04-27 11:21:57,598 - inference - INFO - Predictions for OR.PA made successfully.
# 2025-04-27 11:21:57,668 - inference - INFO - Predictions for LR.PA made successfully.
# 2025-04-27 11:21:57,746 - inference - INFO - Predictions for MC.PA made successfully.
# 2025-04-27 11:21:57,826 - inference - INFO - Predictions for ML.PA made successfully.
# 2025-04-27 11:21:57,900 - inference - INFO - Predictions for ORA.PA made successfully.
# 2025-04-27 11:21:57,984 - inference - INFO - Predictions for RI.PA made successfully.
# 2025-04-27 11:21:58,077 - inference - INFO - Predictions for PUB.PA made successfully.
# 2025-04-27 11:21:58,155 - inference - INFO - Predictions for RNO.PA made successfully.
# 2025-04-27 11:21:58,233 - inference - INFO - Predictions for SAF.PA made successfully.
# 2025-04-27 11:21:58,305 - inference - INFO - Predictions for SGO.PA made successfully.
# 2025-04-27 11:21:58,383 - inference - INFO - Predictions for SAN.PA made successfully.
# 2025-04-27 11:21:58,464 - inference - INFO - Predictions for SU.PA made successfully.
# 2025-04-27 11:21:58,539 - inference - INFO - Predictions for GLE.PA made successfully.
# 2025-04-27 11:21:58,626 - inference - INFO - Predictions for STLAP.PA made successfully.
# 2025-04-27 11:21:58,705 - inference - INFO - Predictions for STMPA.PA made successfully.
# 2025-04-27 11:21:58,791 - inference - INFO - Predictions for TEP.PA made successfully.
# 2025-04-27 11:21:58,875 - inference - INFO - Predictions for HO.PA made successfully.
# 2025-04-27 11:21:58,961 - inference - INFO - Predictions for TTE.PA made successfully.
# 2025-04-27 11:21:59,034 - inference - INFO - Predictions for VIE.PA made successfully.
# 2025-04-27 11:21:59,120 - inference - INFO - Predictions for DG.PA made successfully.
# 2025-04-27 11:21:59,205 - inference - INFO - Predictions for SPY made successfully.
# 2025-04-27 11:21:59,278 - inference - INFO - Predictions for VOO made successfully.
# 2025-04-27 11:21:59,359 - inference - INFO - Predictions for IVV made successfully.
# 2025-04-27 11:21:59,435 - inference - INFO - Predictions for VTI made successfully.
# 2025-04-27 11:21:59,524 - inference - INFO - Predictions for QQQ made successfully.
# 2025-04-27 11:21:59,603 - inference - INFO - Predictions for VEA made successfully.
# 2025-04-27 11:21:59,680 - inference - INFO - Predictions for VUG made successfully.
# 2025-04-27 11:21:59,759 - inference - INFO - Predictions for VTV made successfully.
# 2025-04-27 11:21:59,836 - inference - INFO - Predictions for IEFA made successfully.
# 2025-04-27 11:21:59,911 - inference - INFO - Predictions for AGG made successfully.
# 2025-04-27 11:21:59,993 - inference - INFO - Predictions for BND made successfully.
# 2025-04-27 11:22:00,085 - inference - INFO - Predictions for IWF made successfully.
# 2025-04-27 11:22:00,166 - inference - INFO - Predictions for IJH made successfully.
# 2025-04-27 11:22:00,240 - inference - INFO - Predictions for VIG made successfully.
# 2025-04-27 11:22:00,334 - inference - INFO - Predictions for IJR made successfully.
# 2025-04-27 11:22:00,414 - inference - INFO - Predictions for IEMG made successfully.
# 2025-04-27 11:22:00,502 - inference - INFO - Predictions for VWO made successfully.
# 2025-04-27 11:22:00,582 - inference - INFO - Predictions for VXUS made successfully.
# 2025-04-27 11:22:00,662 - inference - INFO - Predictions for VGT made successfully.
# 2025-04-27 11:22:00,740 - inference - INFO - Predictions for GLD made successfully.
# 2025-04-27 11:22:00,821 - inference - INFO - Predictions for XLK made successfully.
# 2025-04-27 11:22:00,897 - inference - INFO - Predictions for VO made successfully.
# 2025-04-27 11:22:00,974 - inference - INFO - Predictions for IWM made successfully.
# 2025-04-27 11:22:01,058 - inference - INFO - Predictions for RSP made successfully.
# 2025-04-27 11:22:01,139 - inference - INFO - Predictions for ITOT made successfully.
# 2025-04-27 11:22:01,212 - inference - INFO - Predictions for SCHD made successfully.
# 2025-04-27 11:22:01,292 - inference - INFO - Predictions for TLT made successfully.
# 2025-04-27 11:22:01,368 - inference - INFO - Predictions for BNDX made successfully.
# 2025-04-27 11:22:01,443 - inference - INFO - Predictions for VB made successfully.
# 2025-04-27 11:22:01,649 - inference - INFO - Predictions for IWD made successfully.
# 2025-04-27 11:22:01,728 - inference - INFO - Predictions for VYM made successfully.
# 2025-04-27 11:22:01,800 - inference - INFO - Predictions for EFA made successfully.
# 2025-04-27 11:22:01,875 - inference - INFO - Predictions for IVW made successfully.
# 2025-04-27 11:22:01,952 - inference - INFO - Predictions for VCIT made successfully.
# 2025-04-27 11:22:02,034 - inference - INFO - Predictions for QUAL made successfully.
# 2025-04-27 11:22:02,109 - inference - INFO - Predictions for SCHX made successfully.
# 2025-04-27 11:22:02,198 - inference - INFO - Predictions for SPLG made successfully.
# 2025-04-27 11:22:02,281 - inference - INFO - Predictions for SCHF made successfully.
# 2025-04-27 11:22:02,372 - inference - INFO - Predictions for XLF made successfully.
# 2025-04-27 11:22:02,451 - inference - INFO - Predictions for XLV made successfully.
# 2025-04-27 11:22:02,523 - inference - INFO - Predictions for VEU made successfully.
# 2025-04-27 11:22:02,610 - inference - INFO - Predictions for VT made successfully.
# 2025-04-27 11:22:02,694 - inference - INFO - Predictions for IXUS made successfully.
# 2025-04-27 11:22:02,789 - inference - INFO - Predictions for MUB made successfully.
# 2025-04-27 11:22:02,866 - inference - INFO - Predictions for VNQ made successfully.
# 2025-04-27 11:22:02,946 - inference - INFO - Predictions for VV made successfully.
# 2025-04-27 11:22:03,027 - inference - INFO - Predictions for IWB made successfully.
# 2025-04-27 11:22:03,107 - inference - INFO - Predictions for IWR made successfully.
# 2025-04-27 11:22:03,186 - inference - INFO - Predictions for VCSH made successfully.
# 2025-04-27 11:22:03,265 - inference - INFO - Predictions for XLE made successfully.
# 2025-04-27 11:22:03,348 - inference - INFO - Predictions for DIA made successfully.
# 2025-04-27 11:22:03,430 - inference - INFO - Predictions for IVE made successfully.
# 2025-04-27 11:22:03,509 - inference - INFO - Predictions for IEF made successfully.
# 2025-04-27 11:22:03,596 - inference - INFO - Predictions for BSV made successfully.
# 2025-04-27 11:22:03,757 - inference - INFO - Predictions for BIL made successfully.
# 2025-04-27 11:22:03,833 - inference - INFO - Predictions for MBB made successfully.
# 2025-04-27 11:22:03,904 - inference - INFO - Predictions for SCHG made successfully.
# 2025-04-27 11:22:03,979 - inference - INFO - Predictions for IAU made successfully.
# 2025-04-27 11:22:04,062 - inference - INFO - Predictions for SCHB made successfully.
# 2025-04-27 11:22:04,138 - inference - INFO - Predictions for VGIT made successfully.
# 2025-04-27 11:22:04,231 - inference - INFO - Predictions for LQD made successfully.
# 2025-04-27 11:22:04,313 - inference - INFO - Predictions for VBR made successfully.
# 2025-04-27 11:22:04,389 - inference - INFO - Predictions for SPYG made successfully.
# 2025-04-27 11:22:04,470 - inference - INFO - Predictions for GOVT made successfully.
# 2025-04-27 11:22:04,545 - inference - INFO - Predictions for USMV made successfully.
# 2025-04-27 11:22:04,623 - inference - INFO - Predictions for SPYV made successfully.
# 2025-04-27 11:22:04,703 - inference - INFO - Predictions for TQQQ made successfully.
# 2025-04-27 11:22:04,778 - inference - INFO - Predictions for SMH made successfully.
# 2025-04-27 11:22:04,860 - inference - INFO - Predictions for SHY made successfully.
# 2025-04-27 11:22:04,933 - inference - INFO - Predictions for MDY made successfully.
# 2025-04-27 11:22:05,014 - inference - INFO - Predictions for MGK made successfully.
# 2025-04-27 11:22:05,088 - inference - INFO - Predictions for VONG made successfully.
# 2025-04-27 11:22:05,161 - inference - INFO - Predictions for SPDW made successfully.
# 2025-04-27 11:22:05,241 - inference - INFO - Predictions for IGSB made successfully.
# 2025-04-27 11:22:05,319 - inference - INFO - Predictions for SDY made successfully.
# 2025-04-27 11:22:05,389 - inference - INFO - Predictions for VGSH made successfully.
# 2025-04-27 11:22:05,501 - inference - INFO - Predictions for VXF made successfully.
# 2025-04-27 11:22:05,580 - inference - INFO - Predictions for BIV made successfully.
# 2025-04-27 11:22:05,658 - inference - INFO - Predictions for DVY made successfully.
# 2025-04-27 11:22:05,742 - inference - INFO - Predictions for IUSG made successfully.
# 2025-04-27 11:22:05,815 - inference - INFO - Predictions for VGK made successfully.
# 2025-04-27 11:22:05,886 - inference - INFO - Predictions for EFV made successfully.
# 2025-04-27 11:22:05,963 - inference - INFO - Predictions for XLI made successfully.
# 2025-04-27 11:22:06,044 - inference - INFO - Predictions for SHV made successfully.
# 2025-04-27 11:22:06,131 - inference - INFO - Predictions for XLY made successfully.
# 2025-04-27 11:22:06,211 - inference - INFO - Predictions for ACWI made successfully.
# 2025-04-27 11:22:06,296 - inference - INFO - Predictions for IUSV made successfully.
# 2025-04-27 11:22:06,371 - inference - INFO - Predictions for IYW made successfully.
# 2025-04-27 11:22:06,450 - inference - INFO - Predictions for VHT made successfully.
