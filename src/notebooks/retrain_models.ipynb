# %%
import os
import sys
sys.path.append('../')
import logging
import numpy as np
import optuna
from joblib import dump, load

# %%
from util import load_pkl, get_pipline_rf, get_pipline_svr
logger = logging.getLogger('inference')
logger.setLevel(logging.DEBUG)  # Set the logging level

# Prevent adding multiple handlers if this cell is run multiple times
if not logger.handlers:
    # Create a handler that outputs to standard output
    handler = logging.StreamHandler(sys.stdout)

    # Define the log message format
    formatter = logging.Formatter(
        '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
    )
    handler.setFormatter(formatter)

    # Add the handler to the logger
    logger.addHandler(handler)

# %%
logger.debug("This is a debug message.")
# Out:
# 2025-04-27 00:30:59,589 - inference - DEBUG - This is a debug message.

# %%
period = 128
data_dir = f'../../processed_data/processed_data_{period}'

# %%
df_train_X_all = load_pkl(f"{data_dir}/df_train_X_all.pkl")
df_train_y_all = load_pkl(f"{data_dir}/df_train_y_all.pkl")
df_test_X_all = load_pkl(f"{data_dir}/df_test_X_all.pkl")
df_test_y_all = load_pkl(f"{data_dir}/df_test_y_all.pkl")

# %%
# load the valid tickers.
with open(f'{data_dir}/valid_tickers.txt', 'r') as f:
    valid_tickers = f.readlines()

# %%
print(f'Data preparation finished, found {len(valid_tickers)} assets with enough data.')
feature_file_path = os.path.join(data_dir, 'sorted_features.txt')

with open(feature_file_path, 'r') as file:
  sorted_features = np.array(file.read().split('\n'))
  sorted_features = sorted_features[sorted_features != '']
# Out:
# Data preparation finished, found 746 assets with enough data.

# %%
for i in range(len(valid_tickers)):
  df_train_X_all[i] = df_train_X_all[i][sorted_features]
  df_test_X_all[i] = df_test_X_all[i][sorted_features]

# %%
# You can load it back into memory with the following code
# mysql_url = "mysql://root@192.168.2.34:3306/mysql"
postgres_url = "postgresql+psycopg2://postgres:example@192.168.2.34:5432/app_db"
n_columns = len(df_train_X_all[0].columns)
study_rf_name = f'study_rf_columns_{n_columns}_stocks_{len(valid_tickers)}_period_{period}'
study_rf = optuna.create_study(study_name=study_rf_name, storage=postgres_url, load_if_exists=True)
if study_rf.best_trial is None:
  logger.error('No best trial found')
  sys.exit(2)

study_svm_name = f'study_svm_columns_{n_columns}_stocks_{len(valid_tickers)}_period_{period}'
study_svm = optuna.create_study(study_name=study_svm_name, storage=postgres_url, load_if_exists=True)
if study_svm.best_trial is None:
  logger.error('No best trial found')
  sys.exit(2)
# Out:
# [I 2025-04-27 00:23:11,587] Using an existing study with name 'study_rf_columns_28_stocks_746_period_128' instead of creating a new one.
# [I 2025-04-27 00:23:11,741] Using an existing study with name 'study_svm_columns_28_stocks_746_period_128' instead of creating a new one.

# %%
best_pipeline_rf = get_pipline_rf(study_rf.best_params)
best_pipeline_svr = get_pipline_svr(study_svm.best_params)

# %%
for filename in os.listdir(f'{data_dir}/models'):
  if filename.endswith('.pkl'):
    os.remove(os.path.join(f'{data_dir}/models', filename))

# %%
from joblib import dump, load

for i in range(len(valid_tickers)):
  stock_name = valid_tickers[i].strip()
  df_train_X = df_train_X_all[i]
  df_train_y = df_train_y_all[i]
  df_test_X = df_test_X_all[i]
  df_test_y = df_test_y_all[i]

  X_train = df_train_X.copy().values
  y_train = df_train_y.copy().values.ravel()
  X_test = df_test_X.copy().values
  y_test = df_test_y.copy().values.ravel()

  if not os.path.exists(f'{data_dir}/models'):
    os.makedirs(f'{data_dir}/models')


  best_pipeline_rf = get_pipline_rf(study_rf.best_params)
  best_pipeline_rf.fit(X_train, y_train)

  # save the model using joblib

  dump(best_pipeline_rf, f'{data_dir}/models/{stock_name}_rf.joblib')
  logger.info(f"Model for {stock_name} saved successfully.")

  best_pipeline_svr = get_pipline_svr(study_svm.best_params)
  best_pipeline_svr.fit(X_train, y_train)

  # save the model using joblib
  dump(best_pipeline_svr, f'{data_dir}/models/{stock_name}_svr.joblib')
  logger.info(f"Model for {stock_name} saved successfully.")

# %%
for i in range(len(valid_tickers)):
  stock_name = valid_tickers[i].strip()
  df_train_X = df_train_X_all[i]
  df_train_y = df_train_y_all[i]
  df_test_X = df_test_X_all[i]
  df_test_y = df_test_y_all[i]

  X_train = df_train_X.copy().values
  y_train = df_train_y.copy().values.ravel()
  X_test = df_test_X.copy().values
  y_test = df_test_y.copy().values.ravel()

  # load the model using joblib
  loaded_model_rf = load(f'{data_dir}/models/{stock_name}_rf.joblib')

  # make predictions using the loaded model
  predictions_rf = loaded_model_rf.predict(X_test)
  loaded_model_svr = load(f'{data_dir}/models/{stock_name}_svr.joblib')
  predictions_svr = loaded_model_svr.predict(X_test)
  logger.info(f"Predictions for {stock_name} made successfully.")

# %%
import requests
import joblib
from io import BytesIO

# Define the base URL for your Azure Blob Storage
base_url = 'https://stockmodels.blob.core.windows.net/models/'

for i in range(len(valid_tickers)):
    stock_name = valid_tickers[i].strip()
    df_train_X = df_train_X_all[i]
    df_train_y = df_train_y_all[i]
    df_test_X = df_test_X_all[i]
    df_test_y = df_test_y_all[i]

    X_train = df_train_X.copy().values
    y_train = df_train_y.copy().values.ravel()
    X_test = df_test_X.copy().values
    y_test = df_test_y.copy().values.ravel()

    # Construct the full URL for the model
    model_filename = f'{stock_name}_rf.joblib'
    model_url = f'{base_url}{model_filename}'

    try:
        # Send a GET request to download the model file
        response = requests.get(model_url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Load the model from the downloaded content
        model_bytes = BytesIO(response.content)
        loaded_model_rf = joblib.load(model_bytes)

        # Make predictions using the loaded model
        predictions_rf = loaded_model_rf.predict(X_test)
        logger.info(f"Predictions for {stock_name} made successfully.")
        # (Optional) You can add your evaluation metrics here
        # For example:
        # from sklearn.metrics import mean_squared_error
        # mse = mean_squared_error(y_test, predictions_rf)
        # print(f'MSE for {stock_name}: {mse}')

    except requests.exceptions.HTTPError as http_err:
        print(f'HTTP error occurred while downloading {model_filename}: {http_err}')
    except Exception as err:
        print(f'An error occurred while processing {model_filename}: {err}')
# Out:
# 2025-04-27 11:46:12,070 - inference - INFO - Predictions for ADS.DE made successfully.
# 2025-04-27 11:46:12,193 - inference - INFO - Predictions for AIR.DE made successfully.
# 2025-04-27 11:46:12,269 - inference - INFO - Predictions for ALV.DE made successfully.
# 2025-04-27 11:46:12,351 - inference - INFO - Predictions for BAS.DE made successfully.
# 2025-04-27 11:46:12,429 - inference - INFO - Predictions for BAYN.DE made successfully.
# 2025-04-27 11:46:12,502 - inference - INFO - Predictions for BEI.DE made successfully.
# 2025-04-27 11:46:12,579 - inference - INFO - Predictions for BMW.DE made successfully.
# 2025-04-27 11:46:12,654 - inference - INFO - Predictions for BNR.DE made successfully.
# 2025-04-27 11:46:12,732 - inference - INFO - Predictions for CBK.DE made successfully.
# 2025-04-27 11:46:12,811 - inference - INFO - Predictions for CON.DE made successfully.
# 2025-04-27 11:46:12,886 - inference - INFO - Predictions for DBK.DE made successfully.
# 2025-04-27 11:46:12,961 - inference - INFO - Predictions for DB1.DE made successfully.
# 2025-04-27 11:46:13,035 - inference - INFO - Predictions for DHL.DE made successfully.
# 2025-04-27 11:46:13,112 - inference - INFO - Predictions for DTE.DE made successfully.
# 2025-04-27 11:46:13,187 - inference - INFO - Predictions for EOAN.DE made successfully.
# 2025-04-27 11:46:13,265 - inference - INFO - Predictions for FRE.DE made successfully.
# 2025-04-27 11:46:13,344 - inference - INFO - Predictions for HNR1.DE made successfully.
# 2025-04-27 11:46:13,424 - inference - INFO - Predictions for HEI.DE made successfully.
# 2025-04-27 11:46:13,506 - inference - INFO - Predictions for HEN3.DE made successfully.
# 2025-04-27 11:46:13,579 - inference - INFO - Predictions for IFX.DE made successfully.
# 2025-04-27 11:46:13,656 - inference - INFO - Predictions for MBG.DE made successfully.
# 2025-04-27 11:46:13,734 - inference - INFO - Predictions for MRK.DE made successfully.
# 2025-04-27 11:46:13,806 - inference - INFO - Predictions for MTX.DE made successfully.
# 2025-04-27 11:46:13,884 - inference - INFO - Predictions for MUV2.DE made successfully.
# 2025-04-27 11:46:13,956 - inference - INFO - Predictions for PAH3.DE made successfully.
# 2025-04-27 11:46:14,032 - inference - INFO - Predictions for QIA.DE made successfully.
# 2025-04-27 11:46:14,111 - inference - INFO - Predictions for RHM.DE made successfully.
# 2025-04-27 11:46:14,197 - inference - INFO - Predictions for RWE.DE made successfully.
# 2025-04-27 11:46:14,279 - inference - INFO - Predictions for SAP.DE made successfully.
# 2025-04-27 11:46:14,353 - inference - INFO - Predictions for SRT3.DE made successfully.
# 2025-04-27 11:46:14,430 - inference - INFO - Predictions for SIE.DE made successfully.
# 2025-04-27 11:46:14,510 - inference - INFO - Predictions for SY1.DE made successfully.
# 2025-04-27 11:46:14,589 - inference - INFO - Predictions for VOW3.DE made successfully.
# 2025-04-27 11:46:14,668 - inference - INFO - Predictions for VNA.DE made successfully.
# 2025-04-27 11:46:14,743 - inference - INFO - Predictions for III.L made successfully.
# 2025-04-27 11:46:14,820 - inference - INFO - Predictions for ADM.L made successfully.
# 2025-04-27 11:46:14,892 - inference - INFO - Predictions for AAL.L made successfully.
# 2025-04-27 11:46:14,977 - inference - INFO - Predictions for ANTO.L made successfully.
# 2025-04-27 11:46:15,049 - inference - INFO - Predictions for AHT.L made successfully.
# 2025-04-27 11:46:15,129 - inference - INFO - Predictions for ABF.L made successfully.
# 2025-04-27 11:46:15,209 - inference - INFO - Predictions for AZN.L made successfully.
# 2025-04-27 11:46:15,283 - inference - INFO - Predictions for AV.L made successfully.
# 2025-04-27 11:46:15,362 - inference - INFO - Predictions for BA.L made successfully.
# 2025-04-27 11:46:15,440 - inference - INFO - Predictions for BARC.L made successfully.
# 2025-04-27 11:46:15,518 - inference - INFO - Predictions for BDEV.L made successfully.
# 2025-04-27 11:46:15,597 - inference - INFO - Predictions for BEZ.L made successfully.
# 2025-04-27 11:46:15,670 - inference - INFO - Predictions for BKG.L made successfully.
# 2025-04-27 11:46:15,746 - inference - INFO - Predictions for BP.L made successfully.
# 2025-04-27 11:46:15,824 - inference - INFO - Predictions for BATS.L made successfully.
# 2025-04-27 11:46:15,900 - inference - INFO - Predictions for BT-A.L made successfully.
# 2025-04-27 11:46:15,981 - inference - INFO - Predictions for BNZL.L made successfully.
# 2025-04-27 11:46:16,064 - inference - INFO - Predictions for BRBY.L made successfully.
# 2025-04-27 11:46:16,139 - inference - INFO - Predictions for CNA.L made successfully.
# 2025-04-27 11:46:16,213 - inference - INFO - Predictions for CCH.L made successfully.
# 2025-04-27 11:46:16,295 - inference - INFO - Predictions for CPG.L made successfully.
# 2025-04-27 11:46:16,368 - inference - INFO - Predictions for CRDA.L made successfully.
# 2025-04-27 11:46:16,449 - inference - INFO - Predictions for DCC.L made successfully.
# 2025-04-27 11:46:16,522 - inference - INFO - Predictions for DGE.L made successfully.
# 2025-04-27 11:46:16,592 - inference - INFO - Predictions for DPLM.L made successfully.
# 2025-04-27 11:46:16,667 - inference - INFO - Predictions for ENT.L made successfully.
# 2025-04-27 11:46:16,741 - inference - INFO - Predictions for EZJ.L made successfully.
# 2025-04-27 11:46:16,824 - inference - INFO - Predictions for EXPN.L made successfully.
# 2025-04-27 11:46:16,904 - inference - INFO - Predictions for FCIT.L made successfully.
# 2025-04-27 11:46:16,983 - inference - INFO - Predictions for FLTR.L made successfully.
# 2025-04-27 11:46:17,056 - inference - INFO - Predictions for FRAS.L made successfully.
# 2025-04-27 11:46:17,128 - inference - INFO - Predictions for FRES.L made successfully.
# 2025-04-27 11:46:17,200 - inference - INFO - Predictions for GLEN.L made successfully.
# 2025-04-27 11:46:17,275 - inference - INFO - Predictions for GSK.L made successfully.
# 2025-04-27 11:46:17,352 - inference - INFO - Predictions for HLMA.L made successfully.
# 2025-04-27 11:46:17,424 - inference - INFO - Predictions for HIK.L made successfully.
# 2025-04-27 11:46:17,493 - inference - INFO - Predictions for HWDN.L made successfully.
# 2025-04-27 11:46:17,570 - inference - INFO - Predictions for HSBA.L made successfully.
# 2025-04-27 11:46:17,650 - inference - INFO - Predictions for IHG.L made successfully.
# 2025-04-27 11:46:17,722 - inference - INFO - Predictions for IMI.L made successfully.
# 2025-04-27 11:46:17,796 - inference - INFO - Predictions for IMB.L made successfully.
# 2025-04-27 11:46:17,869 - inference - INFO - Predictions for INF.L made successfully.
# 2025-04-27 11:46:17,946 - inference - INFO - Predictions for ICP.L made successfully.
# 2025-04-27 11:46:18,021 - inference - INFO - Predictions for IAG.L made successfully.
# 2025-04-27 11:46:18,094 - inference - INFO - Predictions for ITRK.L made successfully.
# 2025-04-27 11:46:18,164 - inference - INFO - Predictions for JD.L made successfully.
# 2025-04-27 11:46:18,237 - inference - INFO - Predictions for KGF.L made successfully.
# 2025-04-27 11:46:18,316 - inference - INFO - Predictions for LAND.L made successfully.
# 2025-04-27 11:46:18,384 - inference - INFO - Predictions for LGEN.L made successfully.
# 2025-04-27 11:46:18,459 - inference - INFO - Predictions for LLOY.L made successfully.
# 2025-04-27 11:46:18,536 - inference - INFO - Predictions for LSEG.L made successfully.
# 2025-04-27 11:46:18,606 - inference - INFO - Predictions for MKS.L made successfully.
# 2025-04-27 11:46:18,683 - inference - INFO - Predictions for MRO.L made successfully.
# 2025-04-27 11:46:18,755 - inference - INFO - Predictions for MNDI.L made successfully.
# 2025-04-27 11:46:18,838 - inference - INFO - Predictions for NG.L made successfully.
# 2025-04-27 11:46:18,913 - inference - INFO - Predictions for NWG.L made successfully.
# 2025-04-27 11:46:18,985 - inference - INFO - Predictions for NXT.L made successfully.
# 2025-04-27 11:46:19,063 - inference - INFO - Predictions for OCDO.L made successfully.
# 2025-04-27 11:46:19,136 - inference - INFO - Predictions for PSON.L made successfully.
# 2025-04-27 11:46:19,207 - inference - INFO - Predictions for PSN.L made successfully.
# 2025-04-27 11:46:19,277 - inference - INFO - Predictions for PHNX.L made successfully.
# 2025-04-27 11:46:19,355 - inference - INFO - Predictions for PRU.L made successfully.
# 2025-04-27 11:46:19,427 - inference - INFO - Predictions for RKT.L made successfully.
# 2025-04-27 11:46:19,504 - inference - INFO - Predictions for REL.L made successfully.
# 2025-04-27 11:46:19,584 - inference - INFO - Predictions for RTO.L made successfully.
# 2025-04-27 11:46:19,663 - inference - INFO - Predictions for RMV.L made successfully.
# 2025-04-27 11:46:19,739 - inference - INFO - Predictions for RIO.L made successfully.
# 2025-04-27 11:46:19,816 - inference - INFO - Predictions for RR.L made successfully.
# 2025-04-27 11:46:19,889 - inference - INFO - Predictions for RS1.L made successfully.
# 2025-04-27 11:46:19,963 - inference - INFO - Predictions for SGE.L made successfully.
# 2025-04-27 11:46:20,033 - inference - INFO - Predictions for SBRY.L made successfully.
# 2025-04-27 11:46:20,100 - inference - INFO - Predictions for SDR.L made successfully.
# 2025-04-27 11:46:20,170 - inference - INFO - Predictions for SMT.L made successfully.
# 2025-04-27 11:46:20,257 - inference - INFO - Predictions for SGRO.L made successfully.
# 2025-04-27 11:46:20,338 - inference - INFO - Predictions for SVT.L made successfully.
# 2025-04-27 11:46:20,414 - inference - INFO - Predictions for SHEL.L made successfully.
# 2025-04-27 11:46:20,487 - inference - INFO - Predictions for SMDS.L made successfully.
# 2025-04-27 11:46:20,558 - inference - INFO - Predictions for SMIN.L made successfully.
# 2025-04-27 11:46:20,626 - inference - INFO - Predictions for SN.L made successfully.
# 2025-04-27 11:46:20,703 - inference - INFO - Predictions for SKG.L made successfully.
# 2025-04-27 11:46:20,780 - inference - INFO - Predictions for SPX.L made successfully.
# 2025-04-27 11:46:20,862 - inference - INFO - Predictions for SSE.L made successfully.
# 2025-04-27 11:46:20,942 - inference - INFO - Predictions for STAN.L made successfully.
# 2025-04-27 11:46:21,018 - inference - INFO - Predictions for STJ.L made successfully.
# 2025-04-27 11:46:21,093 - inference - INFO - Predictions for TW.L made successfully.
# 2025-04-27 11:46:21,171 - inference - INFO - Predictions for TSCO.L made successfully.
# 2025-04-27 11:46:21,250 - inference - INFO - Predictions for ULVR.L made successfully.
# 2025-04-27 11:46:21,320 - inference - INFO - Predictions for UU.L made successfully.
# 2025-04-27 11:46:21,399 - inference - INFO - Predictions for UTG.L made successfully.
# 2025-04-27 11:46:21,483 - inference - INFO - Predictions for VOD.L made successfully.
# 2025-04-27 11:46:21,561 - inference - INFO - Predictions for WEIR.L made successfully.
# 2025-04-27 11:46:21,645 - inference - INFO - Predictions for WTB.L made successfully.
# 2025-04-27 11:46:21,717 - inference - INFO - Predictions for WPP.L made successfully.
# 2025-04-27 11:46:21,788 - inference - INFO - Predictions for MMM made successfully.
# 2025-04-27 11:46:21,862 - inference - INFO - Predictions for AOS made successfully.
# 2025-04-27 11:46:21,932 - inference - INFO - Predictions for ABT made successfully.
# 2025-04-27 11:46:22,005 - inference - INFO - Predictions for ABBV made successfully.
# 2025-04-27 11:46:22,078 - inference - INFO - Predictions for ACN made successfully.
# 2025-04-27 11:46:22,155 - inference - INFO - Predictions for ADBE made successfully.
# 2025-04-27 11:46:22,224 - inference - INFO - Predictions for AMD made successfully.
# 2025-04-27 11:46:22,294 - inference - INFO - Predictions for AES made successfully.
# 2025-04-27 11:46:22,368 - inference - INFO - Predictions for AFL made successfully.
# 2025-04-27 11:46:22,442 - inference - INFO - Predictions for A made successfully.
# 2025-04-27 11:46:22,519 - inference - INFO - Predictions for APD made successfully.
# 2025-04-27 11:46:22,593 - inference - INFO - Predictions for AKAM made successfully.
# 2025-04-27 11:46:22,667 - inference - INFO - Predictions for ALB made successfully.
# 2025-04-27 11:46:22,736 - inference - INFO - Predictions for ARE made successfully.
# 2025-04-27 11:46:22,809 - inference - INFO - Predictions for ALGN made successfully.
# 2025-04-27 11:46:22,883 - inference - INFO - Predictions for ALLE made successfully.
# 2025-04-27 11:46:22,956 - inference - INFO - Predictions for LNT made successfully.
# 2025-04-27 11:46:23,027 - inference - INFO - Predictions for ALL made successfully.
# 2025-04-27 11:46:23,099 - inference - INFO - Predictions for GOOGL made successfully.
# 2025-04-27 11:46:23,174 - inference - INFO - Predictions for GOOG made successfully.
# 2025-04-27 11:46:23,249 - inference - INFO - Predictions for MO made successfully.
# 2025-04-27 11:46:23,328 - inference - INFO - Predictions for AMZN made successfully.
# 2025-04-27 11:46:23,402 - inference - INFO - Predictions for AMCR made successfully.
# 2025-04-27 11:46:23,475 - inference - INFO - Predictions for AEE made successfully.
# 2025-04-27 11:46:23,548 - inference - INFO - Predictions for AAL made successfully.
# 2025-04-27 11:46:23,625 - inference - INFO - Predictions for AEP made successfully.
# 2025-04-27 11:46:23,700 - inference - INFO - Predictions for AXP made successfully.
# 2025-04-27 11:46:23,801 - inference - INFO - Predictions for AIG made successfully.
# 2025-04-27 11:46:23,877 - inference - INFO - Predictions for AMT made successfully.
# 2025-04-27 11:46:23,948 - inference - INFO - Predictions for AWK made successfully.
# 2025-04-27 11:46:24,023 - inference - INFO - Predictions for AMP made successfully.
# 2025-04-27 11:46:24,108 - inference - INFO - Predictions for AME made successfully.
# 2025-04-27 11:46:24,181 - inference - INFO - Predictions for AMGN made successfully.
# 2025-04-27 11:46:24,259 - inference - INFO - Predictions for APH made successfully.
# 2025-04-27 11:46:24,339 - inference - INFO - Predictions for ADI made successfully.
# 2025-04-27 11:46:24,411 - inference - INFO - Predictions for ANSS made successfully.
# 2025-04-27 11:46:24,488 - inference - INFO - Predictions for AON made successfully.
# 2025-04-27 11:46:24,569 - inference - INFO - Predictions for APA made successfully.
# 2025-04-27 11:46:24,645 - inference - INFO - Predictions for AAPL made successfully.
# 2025-04-27 11:46:24,713 - inference - INFO - Predictions for AMAT made successfully.
# 2025-04-27 11:46:24,788 - inference - INFO - Predictions for APTV made successfully.
# 2025-04-27 11:46:24,858 - inference - INFO - Predictions for ACGL made successfully.
# 2025-04-27 11:46:24,944 - inference - INFO - Predictions for ADM made successfully.
# 2025-04-27 11:46:25,020 - inference - INFO - Predictions for AJG made successfully.
# 2025-04-27 11:46:25,098 - inference - INFO - Predictions for AIZ made successfully.
# 2025-04-27 11:46:25,176 - inference - INFO - Predictions for T made successfully.
# 2025-04-27 11:46:25,248 - inference - INFO - Predictions for ATO made successfully.
# 2025-04-27 11:46:25,329 - inference - INFO - Predictions for ADSK made successfully.
# 2025-04-27 11:46:25,398 - inference - INFO - Predictions for ADP made successfully.
# 2025-04-27 11:46:25,468 - inference - INFO - Predictions for AZO made successfully.
# 2025-04-27 11:46:25,543 - inference - INFO - Predictions for AVB made successfully.
# 2025-04-27 11:46:25,626 - inference - INFO - Predictions for AVY made successfully.
# 2025-04-27 11:46:25,699 - inference - INFO - Predictions for AXON made successfully.
# 2025-04-27 11:46:25,775 - inference - INFO - Predictions for BKR made successfully.
# 2025-04-27 11:46:25,844 - inference - INFO - Predictions for BALL made successfully.
# 2025-04-27 11:46:25,925 - inference - INFO - Predictions for BAC made successfully.
# 2025-04-27 11:46:26,005 - inference - INFO - Predictions for BK made successfully.
# 2025-04-27 11:46:26,077 - inference - INFO - Predictions for BBWI made successfully.
# 2025-04-27 11:46:26,150 - inference - INFO - Predictions for BAX made successfully.
# 2025-04-27 11:46:26,219 - inference - INFO - Predictions for BDX made successfully.
# 2025-04-27 11:46:26,296 - inference - INFO - Predictions for BBY made successfully.
# 2025-04-27 11:46:26,369 - inference - INFO - Predictions for BIO made successfully.
# 2025-04-27 11:46:26,446 - inference - INFO - Predictions for TECH made successfully.
# 2025-04-27 11:46:26,512 - inference - INFO - Predictions for BIIB made successfully.
# 2025-04-27 11:46:26,586 - inference - INFO - Predictions for BLK made successfully.
# 2025-04-27 11:46:26,662 - inference - INFO - Predictions for BX made successfully.
# 2025-04-27 11:46:26,733 - inference - INFO - Predictions for BA made successfully.
# 2025-04-27 11:46:26,804 - inference - INFO - Predictions for BKNG made successfully.
# 2025-04-27 11:46:26,880 - inference - INFO - Predictions for BWA made successfully.
# 2025-04-27 11:46:26,952 - inference - INFO - Predictions for BXP made successfully.
# 2025-04-27 11:46:27,024 - inference - INFO - Predictions for BSX made successfully.
# 2025-04-27 11:46:27,095 - inference - INFO - Predictions for BMY made successfully.
# 2025-04-27 11:46:27,163 - inference - INFO - Predictions for AVGO made successfully.
# 2025-04-27 11:46:27,237 - inference - INFO - Predictions for BR made successfully.
# 2025-04-27 11:46:27,308 - inference - INFO - Predictions for BRO made successfully.
# 2025-04-27 11:46:27,377 - inference - INFO - Predictions for BLDR made successfully.
# 2025-04-27 11:46:27,448 - inference - INFO - Predictions for BG made successfully.
# 2025-04-27 11:46:27,512 - inference - INFO - Predictions for CDNS made successfully.
# 2025-04-27 11:46:27,586 - inference - INFO - Predictions for CPT made successfully.
# 2025-04-27 11:46:27,663 - inference - INFO - Predictions for CPB made successfully.
# 2025-04-27 11:46:27,731 - inference - INFO - Predictions for COF made successfully.
# 2025-04-27 11:46:27,804 - inference - INFO - Predictions for CAH made successfully.
# 2025-04-27 11:46:27,883 - inference - INFO - Predictions for KMX made successfully.
# 2025-04-27 11:46:27,960 - inference - INFO - Predictions for CCL made successfully.
# 2025-04-27 11:46:28,031 - inference - INFO - Predictions for CAT made successfully.
# 2025-04-27 11:46:28,113 - inference - INFO - Predictions for CBOE made successfully.
# 2025-04-27 11:46:28,191 - inference - INFO - Predictions for CBRE made successfully.
# 2025-04-27 11:46:28,262 - inference - INFO - Predictions for CDW made successfully.
# 2025-04-27 11:46:28,338 - inference - INFO - Predictions for CE made successfully.
# 2025-04-27 11:46:28,406 - inference - INFO - Predictions for COR made successfully.
# 2025-04-27 11:46:28,486 - inference - INFO - Predictions for CNC made successfully.
# 2025-04-27 11:46:28,557 - inference - INFO - Predictions for CNP made successfully.
# 2025-04-27 11:46:28,628 - inference - INFO - Predictions for CF made successfully.
# 2025-04-27 11:46:28,706 - inference - INFO - Predictions for CHRW made successfully.
# 2025-04-27 11:46:28,779 - inference - INFO - Predictions for CRL made successfully.
# 2025-04-27 11:46:28,846 - inference - INFO - Predictions for SCHW made successfully.
# 2025-04-27 11:46:28,915 - inference - INFO - Predictions for CHTR made successfully.
# 2025-04-27 11:46:28,986 - inference - INFO - Predictions for CVX made successfully.
# 2025-04-27 11:46:29,059 - inference - INFO - Predictions for CMG made successfully.
# 2025-04-27 11:46:29,136 - inference - INFO - Predictions for CB made successfully.
# 2025-04-27 11:46:29,220 - inference - INFO - Predictions for CHD made successfully.
# 2025-04-27 11:46:29,300 - inference - INFO - Predictions for CI made successfully.
# 2025-04-27 11:46:29,375 - inference - INFO - Predictions for CINF made successfully.
# 2025-04-27 11:46:29,451 - inference - INFO - Predictions for CTAS made successfully.
# 2025-04-27 11:46:29,524 - inference - INFO - Predictions for CSCO made successfully.
# 2025-04-27 11:46:29,594 - inference - INFO - Predictions for C made successfully.
# 2025-04-27 11:46:29,674 - inference - INFO - Predictions for CLX made successfully.
# 2025-04-27 11:46:29,741 - inference - INFO - Predictions for CME made successfully.
# 2025-04-27 11:46:29,812 - inference - INFO - Predictions for CMS made successfully.
# 2025-04-27 11:46:29,888 - inference - INFO - Predictions for KO made successfully.
# 2025-04-27 11:46:29,957 - inference - INFO - Predictions for CTSH made successfully.
# 2025-04-27 11:46:30,030 - inference - INFO - Predictions for CL made successfully.
# 2025-04-27 11:46:30,101 - inference - INFO - Predictions for CMCSA made successfully.
# 2025-04-27 11:46:30,172 - inference - INFO - Predictions for CMA made successfully.
# 2025-04-27 11:46:30,250 - inference - INFO - Predictions for CAG made successfully.
# 2025-04-27 11:46:30,328 - inference - INFO - Predictions for COP made successfully.
# 2025-04-27 11:46:30,399 - inference - INFO - Predictions for ED made successfully.
# 2025-04-27 11:46:30,482 - inference - INFO - Predictions for STZ made successfully.
# 2025-04-27 11:46:30,556 - inference - INFO - Predictions for COO made successfully.
# 2025-04-27 11:46:30,636 - inference - INFO - Predictions for CPRT made successfully.
# 2025-04-27 11:46:30,705 - inference - INFO - Predictions for GLW made successfully.
# 2025-04-27 11:46:30,776 - inference - INFO - Predictions for CPAY made successfully.
# 2025-04-27 11:46:30,841 - inference - INFO - Predictions for CSGP made successfully.
# 2025-04-27 11:46:30,909 - inference - INFO - Predictions for COST made successfully.
# 2025-04-27 11:46:30,980 - inference - INFO - Predictions for CTRA made successfully.
# 2025-04-27 11:46:31,051 - inference - INFO - Predictions for CCI made successfully.
# 2025-04-27 11:46:31,127 - inference - INFO - Predictions for CSX made successfully.
# 2025-04-27 11:46:31,205 - inference - INFO - Predictions for CMI made successfully.
# 2025-04-27 11:46:31,280 - inference - INFO - Predictions for CVS made successfully.
# 2025-04-27 11:46:31,358 - inference - INFO - Predictions for DHR made successfully.
# 2025-04-27 11:46:31,428 - inference - INFO - Predictions for DRI made successfully.
# 2025-04-27 11:46:31,501 - inference - INFO - Predictions for DVA made successfully.
# 2025-04-27 11:46:31,581 - inference - INFO - Predictions for DECK made successfully.
# 2025-04-27 11:46:31,656 - inference - INFO - Predictions for DE made successfully.
# 2025-04-27 11:46:31,723 - inference - INFO - Predictions for DAL made successfully.
# 2025-04-27 11:46:31,798 - inference - INFO - Predictions for DVN made successfully.
# 2025-04-27 11:46:31,870 - inference - INFO - Predictions for DXCM made successfully.
# 2025-04-27 11:46:31,942 - inference - INFO - Predictions for FANG made successfully.
# 2025-04-27 11:46:32,013 - inference - INFO - Predictions for DLR made successfully.
# 2025-04-27 11:46:32,096 - inference - INFO - Predictions for DFS made successfully.
# 2025-04-27 11:46:32,172 - inference - INFO - Predictions for DG made successfully.
# 2025-04-27 11:46:32,248 - inference - INFO - Predictions for DLTR made successfully.
# 2025-04-27 11:46:32,320 - inference - INFO - Predictions for D made successfully.
# 2025-04-27 11:46:32,390 - inference - INFO - Predictions for DPZ made successfully.
# 2025-04-27 11:46:32,463 - inference - INFO - Predictions for DOV made successfully.
# 2025-04-27 11:46:32,526 - inference - INFO - Predictions for DHI made successfully.
# 2025-04-27 11:46:32,596 - inference - INFO - Predictions for DTE made successfully.
# 2025-04-27 11:46:32,673 - inference - INFO - Predictions for DUK made successfully.
# 2025-04-27 11:46:32,744 - inference - INFO - Predictions for DD made successfully.
# 2025-04-27 11:46:32,817 - inference - INFO - Predictions for EMN made successfully.
# 2025-04-27 11:46:32,889 - inference - INFO - Predictions for ETN made successfully.
# 2025-04-27 11:46:32,963 - inference - INFO - Predictions for EBAY made successfully.
# 2025-04-27 11:46:33,035 - inference - INFO - Predictions for ECL made successfully.
# 2025-04-27 11:46:33,113 - inference - INFO - Predictions for EIX made successfully.
# 2025-04-27 11:46:33,194 - inference - INFO - Predictions for EW made successfully.
# 2025-04-27 11:46:33,267 - inference - INFO - Predictions for EA made successfully.
# 2025-04-27 11:46:33,339 - inference - INFO - Predictions for ELV made successfully.
# 2025-04-27 11:46:33,415 - inference - INFO - Predictions for LLY made successfully.
# 2025-04-27 11:46:33,491 - inference - INFO - Predictions for EMR made successfully.
# 2025-04-27 11:46:33,564 - inference - INFO - Predictions for ENPH made successfully.
# 2025-04-27 11:46:33,635 - inference - INFO - Predictions for ETR made successfully.
# 2025-04-27 11:46:33,706 - inference - INFO - Predictions for EOG made successfully.
# 2025-04-27 11:46:33,778 - inference - INFO - Predictions for EPAM made successfully.
# 2025-04-27 11:46:33,850 - inference - INFO - Predictions for EQT made successfully.
# 2025-04-27 11:46:33,925 - inference - INFO - Predictions for EFX made successfully.
# 2025-04-27 11:46:33,993 - inference - INFO - Predictions for EQIX made successfully.
# 2025-04-27 11:46:34,068 - inference - INFO - Predictions for EQR made successfully.
# 2025-04-27 11:46:34,135 - inference - INFO - Predictions for ESS made successfully.
# 2025-04-27 11:46:34,207 - inference - INFO - Predictions for EL made successfully.
# 2025-04-27 11:46:34,282 - inference - INFO - Predictions for EG made successfully.
# 2025-04-27 11:46:34,355 - inference - INFO - Predictions for EVRG made successfully.
# 2025-04-27 11:46:34,428 - inference - INFO - Predictions for ES made successfully.
# 2025-04-27 11:46:34,495 - inference - INFO - Predictions for EXC made successfully.
# 2025-04-27 11:46:34,564 - inference - INFO - Predictions for EXPE made successfully.
# 2025-04-27 11:46:34,640 - inference - INFO - Predictions for EXPD made successfully.
# 2025-04-27 11:46:34,718 - inference - INFO - Predictions for EXR made successfully.
# 2025-04-27 11:46:34,789 - inference - INFO - Predictions for XOM made successfully.
# 2025-04-27 11:46:34,859 - inference - INFO - Predictions for FFIV made successfully.
# 2025-04-27 11:46:34,933 - inference - INFO - Predictions for FDS made successfully.
# 2025-04-27 11:46:35,009 - inference - INFO - Predictions for FICO made successfully.
# 2025-04-27 11:46:35,084 - inference - INFO - Predictions for FAST made successfully.
# 2025-04-27 11:46:35,153 - inference - INFO - Predictions for FRT made successfully.
# 2025-04-27 11:46:35,226 - inference - INFO - Predictions for FDX made successfully.
# 2025-04-27 11:46:35,298 - inference - INFO - Predictions for FIS made successfully.
# 2025-04-27 11:46:35,376 - inference - INFO - Predictions for FITB made successfully.
# 2025-04-27 11:46:35,454 - inference - INFO - Predictions for FSLR made successfully.
# 2025-04-27 11:46:35,540 - inference - INFO - Predictions for FE made successfully.
# 2025-04-27 11:46:35,614 - inference - INFO - Predictions for FI made successfully.
# 2025-04-27 11:46:35,686 - inference - INFO - Predictions for FMC made successfully.
# 2025-04-27 11:46:35,759 - inference - INFO - Predictions for F made successfully.
# 2025-04-27 11:46:35,825 - inference - INFO - Predictions for FTNT made successfully.
# 2025-04-27 11:46:35,919 - inference - INFO - Predictions for BEN made successfully.
# 2025-04-27 11:46:35,991 - inference - INFO - Predictions for FCX made successfully.
# 2025-04-27 11:46:36,068 - inference - INFO - Predictions for GRMN made successfully.
# 2025-04-27 11:46:36,139 - inference - INFO - Predictions for IT made successfully.
# 2025-04-27 11:46:36,212 - inference - INFO - Predictions for GE made successfully.
# 2025-04-27 11:46:36,282 - inference - INFO - Predictions for GEN made successfully.
# 2025-04-27 11:46:36,356 - inference - INFO - Predictions for GNRC made successfully.
# 2025-04-27 11:46:36,427 - inference - INFO - Predictions for GD made successfully.
# 2025-04-27 11:46:36,515 - inference - INFO - Predictions for GIS made successfully.
# 2025-04-27 11:46:36,591 - inference - INFO - Predictions for GM made successfully.
# 2025-04-27 11:46:36,662 - inference - INFO - Predictions for GPC made successfully.
# 2025-04-27 11:46:36,739 - inference - INFO - Predictions for GILD made successfully.
# 2025-04-27 11:46:36,810 - inference - INFO - Predictions for GPN made successfully.
# 2025-04-27 11:46:36,887 - inference - INFO - Predictions for GL made successfully.
# 2025-04-27 11:46:36,970 - inference - INFO - Predictions for GS made successfully.
# 2025-04-27 11:46:37,052 - inference - INFO - Predictions for HAL made successfully.
# 2025-04-27 11:46:37,124 - inference - INFO - Predictions for HIG made successfully.
# 2025-04-27 11:46:37,197 - inference - INFO - Predictions for HAS made successfully.
# 2025-04-27 11:46:37,272 - inference - INFO - Predictions for HCA made successfully.
# 2025-04-27 11:46:37,341 - inference - INFO - Predictions for DOC made successfully.
# 2025-04-27 11:46:37,412 - inference - INFO - Predictions for HSIC made successfully.
# 2025-04-27 11:46:37,486 - inference - INFO - Predictions for HSY made successfully.
# 2025-04-27 11:46:37,561 - inference - INFO - Predictions for HES made successfully.
# 2025-04-27 11:46:37,627 - inference - INFO - Predictions for HLT made successfully.
# 2025-04-27 11:46:37,692 - inference - INFO - Predictions for HOLX made successfully.
# 2025-04-27 11:46:37,762 - inference - INFO - Predictions for HD made successfully.
# 2025-04-27 11:46:37,840 - inference - INFO - Predictions for HON made successfully.
# 2025-04-27 11:46:37,908 - inference - INFO - Predictions for HRL made successfully.
# 2025-04-27 11:46:37,977 - inference - INFO - Predictions for HST made successfully.
# 2025-04-27 11:46:38,049 - inference - INFO - Predictions for HPQ made successfully.
# 2025-04-27 11:46:38,131 - inference - INFO - Predictions for HUBB made successfully.
# 2025-04-27 11:46:38,204 - inference - INFO - Predictions for HUM made successfully.
# 2025-04-27 11:46:38,276 - inference - INFO - Predictions for HBAN made successfully.
# 2025-04-27 11:46:38,350 - inference - INFO - Predictions for HII made successfully.
# 2025-04-27 11:46:38,420 - inference - INFO - Predictions for IBM made successfully.
# 2025-04-27 11:46:38,494 - inference - INFO - Predictions for IEX made successfully.
# 2025-04-27 11:46:38,562 - inference - INFO - Predictions for IDXX made successfully.
# 2025-04-27 11:46:38,634 - inference - INFO - Predictions for ITW made successfully.
# 2025-04-27 11:46:38,704 - inference - INFO - Predictions for ILMN made successfully.
# 2025-04-27 11:46:38,775 - inference - INFO - Predictions for INCY made successfully.
# 2025-04-27 11:46:38,849 - inference - INFO - Predictions for PODD made successfully.
# 2025-04-27 11:46:38,918 - inference - INFO - Predictions for INTC made successfully.
# 2025-04-27 11:46:38,990 - inference - INFO - Predictions for ICE made successfully.
# 2025-04-27 11:46:39,058 - inference - INFO - Predictions for IFF made successfully.
# 2025-04-27 11:46:39,135 - inference - INFO - Predictions for IP made successfully.
# 2025-04-27 11:46:39,212 - inference - INFO - Predictions for IPG made successfully.
# 2025-04-27 11:46:39,288 - inference - INFO - Predictions for INTU made successfully.
# 2025-04-27 11:46:39,370 - inference - INFO - Predictions for ISRG made successfully.
# 2025-04-27 11:46:39,443 - inference - INFO - Predictions for IVZ made successfully.
# 2025-04-27 11:46:39,513 - inference - INFO - Predictions for IQV made successfully.
# 2025-04-27 11:46:39,589 - inference - INFO - Predictions for IRM made successfully.
# 2025-04-27 11:46:39,661 - inference - INFO - Predictions for JBHT made successfully.
# 2025-04-27 11:46:39,730 - inference - INFO - Predictions for JBL made successfully.
# 2025-04-27 11:46:39,798 - inference - INFO - Predictions for JKHY made successfully.
# 2025-04-27 11:46:39,868 - inference - INFO - Predictions for J made successfully.
# 2025-04-27 11:46:39,938 - inference - INFO - Predictions for JNJ made successfully.
# 2025-04-27 11:46:40,018 - inference - INFO - Predictions for JCI made successfully.
# 2025-04-27 11:46:40,088 - inference - INFO - Predictions for JPM made successfully.
# 2025-04-27 11:46:40,175 - inference - INFO - Predictions for JNPR made successfully.
# 2025-04-27 11:46:40,248 - inference - INFO - Predictions for K made successfully.
# 2025-04-27 11:46:40,326 - inference - INFO - Predictions for KDP made successfully.
# 2025-04-27 11:46:40,398 - inference - INFO - Predictions for KEY made successfully.
# 2025-04-27 11:46:40,469 - inference - INFO - Predictions for KMB made successfully.
# 2025-04-27 11:46:40,538 - inference - INFO - Predictions for KIM made successfully.
# 2025-04-27 11:46:40,609 - inference - INFO - Predictions for KMI made successfully.
# 2025-04-27 11:46:40,678 - inference - INFO - Predictions for KLAC made successfully.
# 2025-04-27 11:46:40,742 - inference - INFO - Predictions for KR made successfully.
# 2025-04-27 11:46:40,815 - inference - INFO - Predictions for LHX made successfully.
# 2025-04-27 11:46:40,885 - inference - INFO - Predictions for LH made successfully.
# 2025-04-27 11:46:40,961 - inference - INFO - Predictions for LRCX made successfully.
# 2025-04-27 11:46:41,030 - inference - INFO - Predictions for LVS made successfully.
# 2025-04-27 11:46:41,100 - inference - INFO - Predictions for LDOS made successfully.
# 2025-04-27 11:46:41,172 - inference - INFO - Predictions for LEN made successfully.
# 2025-04-27 11:46:41,251 - inference - INFO - Predictions for LIN made successfully.
# 2025-04-27 11:46:41,317 - inference - INFO - Predictions for LYV made successfully.
# 2025-04-27 11:46:41,385 - inference - INFO - Predictions for LKQ made successfully.
# 2025-04-27 11:46:41,455 - inference - INFO - Predictions for LMT made successfully.
# 2025-04-27 11:46:41,528 - inference - INFO - Predictions for L made successfully.
# 2025-04-27 11:46:41,597 - inference - INFO - Predictions for LOW made successfully.
# 2025-04-27 11:46:41,671 - inference - INFO - Predictions for LULU made successfully.
# 2025-04-27 11:46:41,737 - inference - INFO - Predictions for LYB made successfully.
# 2025-04-27 11:46:41,810 - inference - INFO - Predictions for MTB made successfully.
# 2025-04-27 11:46:41,890 - inference - INFO - Predictions for MRO made successfully.
# 2025-04-27 11:46:41,956 - inference - INFO - Predictions for MPC made successfully.
# 2025-04-27 11:46:42,026 - inference - INFO - Predictions for MKTX made successfully.
# 2025-04-27 11:46:42,093 - inference - INFO - Predictions for MAR made successfully.
# 2025-04-27 11:46:42,163 - inference - INFO - Predictions for MMC made successfully.
# 2025-04-27 11:46:42,236 - inference - INFO - Predictions for MLM made successfully.
# 2025-04-27 11:46:42,314 - inference - INFO - Predictions for MAS made successfully.
# 2025-04-27 11:46:42,389 - inference - INFO - Predictions for MA made successfully.
# 2025-04-27 11:46:42,465 - inference - INFO - Predictions for MTCH made successfully.
# 2025-04-27 11:46:42,539 - inference - INFO - Predictions for MKC made successfully.
# 2025-04-27 11:46:42,611 - inference - INFO - Predictions for MCD made successfully.
# 2025-04-27 11:46:42,677 - inference - INFO - Predictions for MCK made successfully.
# 2025-04-27 11:46:42,749 - inference - INFO - Predictions for MDT made successfully.
# 2025-04-27 11:46:42,840 - inference - INFO - Predictions for MRK made successfully.
# 2025-04-27 11:46:42,910 - inference - INFO - Predictions for META made successfully.
# 2025-04-27 11:46:42,983 - inference - INFO - Predictions for MET made successfully.
# 2025-04-27 11:46:43,055 - inference - INFO - Predictions for MTD made successfully.
# 2025-04-27 11:46:43,128 - inference - INFO - Predictions for MGM made successfully.
# 2025-04-27 11:46:43,200 - inference - INFO - Predictions for MCHP made successfully.
# 2025-04-27 11:46:43,274 - inference - INFO - Predictions for MU made successfully.
# 2025-04-27 11:46:43,349 - inference - INFO - Predictions for MSFT made successfully.
# 2025-04-27 11:46:43,422 - inference - INFO - Predictions for MAA made successfully.
# 2025-04-27 11:46:43,493 - inference - INFO - Predictions for MHK made successfully.
# 2025-04-27 11:46:43,564 - inference - INFO - Predictions for MOH made successfully.
# 2025-04-27 11:46:43,633 - inference - INFO - Predictions for TAP made successfully.
# 2025-04-27 11:46:43,707 - inference - INFO - Predictions for MDLZ made successfully.
# 2025-04-27 11:46:43,780 - inference - INFO - Predictions for MPWR made successfully.
# 2025-04-27 11:46:43,850 - inference - INFO - Predictions for MNST made successfully.
# 2025-04-27 11:46:43,925 - inference - INFO - Predictions for MCO made successfully.
# 2025-04-27 11:46:43,995 - inference - INFO - Predictions for MS made successfully.
# 2025-04-27 11:46:44,068 - inference - INFO - Predictions for MOS made successfully.
# 2025-04-27 11:46:44,142 - inference - INFO - Predictions for MSI made successfully.
# 2025-04-27 11:46:44,355 - inference - INFO - Predictions for MSCI made successfully.
# 2025-04-27 11:46:44,431 - inference - INFO - Predictions for NDAQ made successfully.
# 2025-04-27 11:46:44,500 - inference - INFO - Predictions for NTAP made successfully.
# 2025-04-27 11:46:44,571 - inference - INFO - Predictions for NFLX made successfully.
# 2025-04-27 11:46:44,643 - inference - INFO - Predictions for NEM made successfully.
# 2025-04-27 11:46:44,716 - inference - INFO - Predictions for NWSA made successfully.
# 2025-04-27 11:46:44,780 - inference - INFO - Predictions for NWS made successfully.
# 2025-04-27 11:46:44,854 - inference - INFO - Predictions for NEE made successfully.
# 2025-04-27 11:46:44,930 - inference - INFO - Predictions for NKE made successfully.
# 2025-04-27 11:46:44,997 - inference - INFO - Predictions for NI made successfully.
# 2025-04-27 11:46:45,070 - inference - INFO - Predictions for NDSN made successfully.
# 2025-04-27 11:46:45,140 - inference - INFO - Predictions for NSC made successfully.
# 2025-04-27 11:46:45,216 - inference - INFO - Predictions for NTRS made successfully.
# 2025-04-27 11:46:45,289 - inference - INFO - Predictions for NOC made successfully.
# 2025-04-27 11:46:45,359 - inference - INFO - Predictions for NCLH made successfully.
# 2025-04-27 11:46:45,434 - inference - INFO - Predictions for NRG made successfully.
# 2025-04-27 11:46:45,511 - inference - INFO - Predictions for NUE made successfully.
# 2025-04-27 11:46:45,577 - inference - INFO - Predictions for NVDA made successfully.
# 2025-04-27 11:46:45,648 - inference - INFO - Predictions for NVR made successfully.
# 2025-04-27 11:46:45,720 - inference - INFO - Predictions for NXPI made successfully.
# 2025-04-27 11:46:45,800 - inference - INFO - Predictions for ORLY made successfully.
# 2025-04-27 11:46:45,868 - inference - INFO - Predictions for OXY made successfully.
# 2025-04-27 11:46:45,940 - inference - INFO - Predictions for ODFL made successfully.
# 2025-04-27 11:46:46,009 - inference - INFO - Predictions for OMC made successfully.
# 2025-04-27 11:46:46,101 - inference - INFO - Predictions for ON made successfully.
# 2025-04-27 11:46:46,177 - inference - INFO - Predictions for OKE made successfully.
# 2025-04-27 11:46:46,259 - inference - INFO - Predictions for ORCL made successfully.
# 2025-04-27 11:46:46,330 - inference - INFO - Predictions for PCAR made successfully.
# 2025-04-27 11:46:46,409 - inference - INFO - Predictions for PKG made successfully.
# 2025-04-27 11:46:46,485 - inference - INFO - Predictions for PANW made successfully.
# 2025-04-27 11:46:46,552 - inference - INFO - Predictions for PARA made successfully.
# 2025-04-27 11:46:46,622 - inference - INFO - Predictions for PH made successfully.
# 2025-04-27 11:46:46,691 - inference - INFO - Predictions for PAYX made successfully.
# 2025-04-27 11:46:46,761 - inference - INFO - Predictions for PNR made successfully.
# 2025-04-27 11:46:46,830 - inference - INFO - Predictions for PEP made successfully.
# 2025-04-27 11:46:46,905 - inference - INFO - Predictions for PFE made successfully.
# 2025-04-27 11:46:46,976 - inference - INFO - Predictions for PCG made successfully.
# 2025-04-27 11:46:47,049 - inference - INFO - Predictions for PM made successfully.
# 2025-04-27 11:46:47,120 - inference - INFO - Predictions for PSX made successfully.
# 2025-04-27 11:46:47,204 - inference - INFO - Predictions for PNW made successfully.
# 2025-04-27 11:46:47,275 - inference - INFO - Predictions for PXD made successfully.
# 2025-04-27 11:46:47,342 - inference - INFO - Predictions for PNC made successfully.
# 2025-04-27 11:46:47,417 - inference - INFO - Predictions for POOL made successfully.
# 2025-04-27 11:46:47,488 - inference - INFO - Predictions for PPG made successfully.
# 2025-04-27 11:46:47,562 - inference - INFO - Predictions for PPL made successfully.
# 2025-04-27 11:46:47,646 - inference - INFO - Predictions for PFG made successfully.
# 2025-04-27 11:46:47,722 - inference - INFO - Predictions for PG made successfully.
# 2025-04-27 11:46:47,796 - inference - INFO - Predictions for PGR made successfully.
# 2025-04-27 11:46:47,862 - inference - INFO - Predictions for PLD made successfully.
# 2025-04-27 11:46:47,934 - inference - INFO - Predictions for PRU made successfully.
# 2025-04-27 11:46:48,009 - inference - INFO - Predictions for PEG made successfully.
# 2025-04-27 11:46:48,084 - inference - INFO - Predictions for PTC made successfully.
# 2025-04-27 11:46:48,162 - inference - INFO - Predictions for PSA made successfully.
# 2025-04-27 11:46:48,242 - inference - INFO - Predictions for PHM made successfully.
# 2025-04-27 11:46:48,334 - inference - INFO - Predictions for PWR made successfully.
# 2025-04-27 11:46:48,411 - inference - INFO - Predictions for QCOM made successfully.
# 2025-04-27 11:46:48,484 - inference - INFO - Predictions for DGX made successfully.
# 2025-04-27 11:46:48,557 - inference - INFO - Predictions for RL made successfully.
# 2025-04-27 11:46:48,629 - inference - INFO - Predictions for RJF made successfully.
# 2025-04-27 11:46:48,714 - inference - INFO - Predictions for RTX made successfully.
# 2025-04-27 11:46:48,785 - inference - INFO - Predictions for O made successfully.
# 2025-04-27 11:46:48,861 - inference - INFO - Predictions for REG made successfully.
# 2025-04-27 11:46:48,932 - inference - INFO - Predictions for REGN made successfully.
# 2025-04-27 11:46:49,006 - inference - INFO - Predictions for RF made successfully.
# 2025-04-27 11:46:49,076 - inference - INFO - Predictions for RSG made successfully.
# 2025-04-27 11:46:49,150 - inference - INFO - Predictions for RMD made successfully.
# 2025-04-27 11:46:49,227 - inference - INFO - Predictions for RVTY made successfully.
# 2025-04-27 11:46:49,297 - inference - INFO - Predictions for RHI made successfully.
# 2025-04-27 11:46:49,361 - inference - INFO - Predictions for ROK made successfully.
# 2025-04-27 11:46:49,432 - inference - INFO - Predictions for ROL made successfully.
# 2025-04-27 11:46:49,499 - inference - INFO - Predictions for ROP made successfully.
# 2025-04-27 11:46:49,580 - inference - INFO - Predictions for ROST made successfully.
# 2025-04-27 11:46:49,662 - inference - INFO - Predictions for RCL made successfully.
# 2025-04-27 11:46:49,739 - inference - INFO - Predictions for SPGI made successfully.
# 2025-04-27 11:46:49,817 - inference - INFO - Predictions for CRM made successfully.
# 2025-04-27 11:46:49,894 - inference - INFO - Predictions for SBAC made successfully.
# 2025-04-27 11:46:49,967 - inference - INFO - Predictions for SLB made successfully.
# 2025-04-27 11:46:50,040 - inference - INFO - Predictions for STX made successfully.
# 2025-04-27 11:46:50,144 - inference - INFO - Predictions for SRE made successfully.
# 2025-04-27 11:46:50,210 - inference - INFO - Predictions for NOW made successfully.
# 2025-04-27 11:46:51,323 - inference - INFO - Predictions for SHW made successfully.
# 2025-04-27 11:46:51,394 - inference - INFO - Predictions for SPG made successfully.
# 2025-04-27 11:46:51,467 - inference - INFO - Predictions for SWKS made successfully.
# 2025-04-27 11:46:51,543 - inference - INFO - Predictions for SJM made successfully.
# 2025-04-27 11:46:51,619 - inference - INFO - Predictions for SNA made successfully.
# 2025-04-27 11:46:51,691 - inference - INFO - Predictions for SO made successfully.
# 2025-04-27 11:46:51,768 - inference - INFO - Predictions for LUV made successfully.
# 2025-04-27 11:46:51,843 - inference - INFO - Predictions for SWK made successfully.
# 2025-04-27 11:46:51,921 - inference - INFO - Predictions for SBUX made successfully.
# 2025-04-27 11:46:51,992 - inference - INFO - Predictions for STT made successfully.
# 2025-04-27 11:46:52,065 - inference - INFO - Predictions for STLD made successfully.
# 2025-04-27 11:46:52,137 - inference - INFO - Predictions for STE made successfully.
# 2025-04-27 11:46:52,202 - inference - INFO - Predictions for SYK made successfully.
# 2025-04-27 11:46:52,275 - inference - INFO - Predictions for SMCI made successfully.
# 2025-04-27 11:46:52,355 - inference - INFO - Predictions for SNPS made successfully.
# 2025-04-27 11:46:52,433 - inference - INFO - Predictions for SYY made successfully.
# 2025-04-27 11:46:52,501 - inference - INFO - Predictions for TMUS made successfully.
# 2025-04-27 11:46:52,574 - inference - INFO - Predictions for TROW made successfully.
# 2025-04-27 11:46:52,668 - inference - INFO - Predictions for TTWO made successfully.
# 2025-04-27 11:46:52,741 - inference - INFO - Predictions for TPR made successfully.
# 2025-04-27 11:46:52,808 - inference - INFO - Predictions for TRGP made successfully.
# 2025-04-27 11:46:52,889 - inference - INFO - Predictions for TGT made successfully.
# 2025-04-27 11:46:52,954 - inference - INFO - Predictions for TEL made successfully.
# 2025-04-27 11:46:53,024 - inference - INFO - Predictions for TDY made successfully.
# 2025-04-27 11:46:53,096 - inference - INFO - Predictions for TFX made successfully.
# 2025-04-27 11:46:53,172 - inference - INFO - Predictions for TER made successfully.
# 2025-04-27 11:46:53,247 - inference - INFO - Predictions for TSLA made successfully.
# 2025-04-27 11:46:53,323 - inference - INFO - Predictions for TXN made successfully.
# 2025-04-27 11:46:53,399 - inference - INFO - Predictions for TXT made successfully.
# 2025-04-27 11:46:53,469 - inference - INFO - Predictions for TMO made successfully.
# 2025-04-27 11:46:53,536 - inference - INFO - Predictions for TJX made successfully.
# 2025-04-27 11:46:53,618 - inference - INFO - Predictions for TSCO made successfully.
# 2025-04-27 11:46:53,687 - inference - INFO - Predictions for TT made successfully.
# 2025-04-27 11:46:53,759 - inference - INFO - Predictions for TDG made successfully.
# 2025-04-27 11:46:53,833 - inference - INFO - Predictions for TRV made successfully.
# 2025-04-27 11:46:53,907 - inference - INFO - Predictions for TRMB made successfully.
# 2025-04-27 11:46:53,982 - inference - INFO - Predictions for TFC made successfully.
# 2025-04-27 11:46:54,053 - inference - INFO - Predictions for TYL made successfully.
# 2025-04-27 11:46:54,124 - inference - INFO - Predictions for TSN made successfully.
# 2025-04-27 11:46:54,202 - inference - INFO - Predictions for USB made successfully.
# 2025-04-27 11:46:54,277 - inference - INFO - Predictions for UDR made successfully.
# 2025-04-27 11:46:54,347 - inference - INFO - Predictions for ULTA made successfully.
# 2025-04-27 11:46:54,420 - inference - INFO - Predictions for UNP made successfully.
# 2025-04-27 11:46:54,491 - inference - INFO - Predictions for UAL made successfully.
# 2025-04-27 11:46:54,566 - inference - INFO - Predictions for UPS made successfully.
# 2025-04-27 11:46:54,636 - inference - INFO - Predictions for URI made successfully.
# 2025-04-27 11:46:54,703 - inference - INFO - Predictions for UNH made successfully.
# 2025-04-27 11:46:54,773 - inference - INFO - Predictions for UHS made successfully.
# 2025-04-27 11:46:54,844 - inference - INFO - Predictions for VLO made successfully.
# 2025-04-27 11:46:54,909 - inference - INFO - Predictions for VTR made successfully.
# 2025-04-27 11:46:54,981 - inference - INFO - Predictions for VRSN made successfully.
# 2025-04-27 11:46:55,054 - inference - INFO - Predictions for VRSK made successfully.
# 2025-04-27 11:46:55,128 - inference - INFO - Predictions for VZ made successfully.
# 2025-04-27 11:46:55,203 - inference - INFO - Predictions for VRTX made successfully.
# 2025-04-27 11:46:55,279 - inference - INFO - Predictions for VTRS made successfully.
# 2025-04-27 11:46:55,351 - inference - INFO - Predictions for V made successfully.
# 2025-04-27 11:46:55,428 - inference - INFO - Predictions for VMC made successfully.
# 2025-04-27 11:46:55,509 - inference - INFO - Predictions for WRB made successfully.
# 2025-04-27 11:46:55,582 - inference - INFO - Predictions for WAB made successfully.
# 2025-04-27 11:46:55,652 - inference - INFO - Predictions for WBA made successfully.
# 2025-04-27 11:46:55,726 - inference - INFO - Predictions for WMT made successfully.
# 2025-04-27 11:46:55,796 - inference - INFO - Predictions for DIS made successfully.
# 2025-04-27 11:46:55,872 - inference - INFO - Predictions for WBD made successfully.
# 2025-04-27 11:46:55,944 - inference - INFO - Predictions for WM made successfully.
# 2025-04-27 11:46:56,013 - inference - INFO - Predictions for WAT made successfully.
# 2025-04-27 11:46:56,087 - inference - INFO - Predictions for WEC made successfully.
# 2025-04-27 11:46:56,159 - inference - INFO - Predictions for WFC made successfully.
# 2025-04-27 11:46:56,232 - inference - INFO - Predictions for WELL made successfully.
# 2025-04-27 11:46:56,304 - inference - INFO - Predictions for WST made successfully.
# 2025-04-27 11:46:56,371 - inference - INFO - Predictions for WDC made successfully.
# 2025-04-27 11:46:56,444 - inference - INFO - Predictions for WY made successfully.
# 2025-04-27 11:46:56,517 - inference - INFO - Predictions for WMB made successfully.
# 2025-04-27 11:46:56,592 - inference - INFO - Predictions for WTW made successfully.
# 2025-04-27 11:46:56,663 - inference - INFO - Predictions for GWW made successfully.
# 2025-04-27 11:46:56,735 - inference - INFO - Predictions for WYNN made successfully.
# 2025-04-27 11:46:56,809 - inference - INFO - Predictions for XEL made successfully.
# 2025-04-27 11:46:56,882 - inference - INFO - Predictions for XYL made successfully.
# 2025-04-27 11:46:56,963 - inference - INFO - Predictions for YUM made successfully.
# 2025-04-27 11:46:57,036 - inference - INFO - Predictions for ZBRA made successfully.
# 2025-04-27 11:46:57,111 - inference - INFO - Predictions for ZBH made successfully.
# 2025-04-27 11:46:57,185 - inference - INFO - Predictions for ZTS made successfully.
# 2025-04-27 11:46:57,254 - inference - INFO - Predictions for ABB.ST made successfully.
# 2025-04-27 11:46:57,326 - inference - INFO - Predictions for ALFA.ST made successfully.
# 2025-04-27 11:46:57,404 - inference - INFO - Predictions for ASSA-B.ST made successfully.
# 2025-04-27 11:46:57,475 - inference - INFO - Predictions for AZN.ST made successfully.
# 2025-04-27 11:46:57,543 - inference - INFO - Predictions for ATCO-A.ST made successfully.
# 2025-04-27 11:46:57,621 - inference - INFO - Predictions for ATCO-B.ST made successfully.
# 2025-04-27 11:46:57,709 - inference - INFO - Predictions for ALIV-SDB.ST made successfully.
# 2025-04-27 11:46:57,784 - inference - INFO - Predictions for BOL.ST made successfully.
# 2025-04-27 11:46:57,852 - inference - INFO - Predictions for ELUX-B.ST made successfully.
# 2025-04-27 11:46:57,925 - inference - INFO - Predictions for ERIC-B.ST made successfully.
# 2025-04-27 11:46:57,997 - inference - INFO - Predictions for GETI-B.ST made successfully.
# 2025-04-27 11:46:58,068 - inference - INFO - Predictions for HM-B.ST made successfully.
# 2025-04-27 11:46:58,141 - inference - INFO - Predictions for HEXA-B.ST made successfully.
# 2025-04-27 11:46:58,210 - inference - INFO - Predictions for INVE-B.ST made successfully.
# 2025-04-27 11:46:58,286 - inference - INFO - Predictions for KINV-B.ST made successfully.
# 2025-04-27 11:46:58,359 - inference - INFO - Predictions for NDA-SE.ST made successfully.
# 2025-04-27 11:46:58,432 - inference - INFO - Predictions for SAND.ST made successfully.
# 2025-04-27 11:46:58,497 - inference - INFO - Predictions for SEB-A.ST made successfully.
# 2025-04-27 11:46:58,571 - inference - INFO - Predictions for SKA-B.ST made successfully.
# 2025-04-27 11:46:58,636 - inference - INFO - Predictions for SKF-B.ST made successfully.
# 2025-04-27 11:46:58,708 - inference - INFO - Predictions for SCA-B.ST made successfully.
# 2025-04-27 11:46:58,776 - inference - INFO - Predictions for SHB-A.ST made successfully.
# 2025-04-27 11:46:58,844 - inference - INFO - Predictions for SWED-A.ST made successfully.
# 2025-04-27 11:46:58,923 - inference - INFO - Predictions for TEL2-B.ST made successfully.
# 2025-04-27 11:46:58,994 - inference - INFO - Predictions for TELIA.ST made successfully.
# 2025-04-27 11:46:59,068 - inference - INFO - Predictions for VOLV-B.ST made successfully.
# 2025-04-27 11:46:59,146 - inference - INFO - Predictions for AI.PA made successfully.
# 2025-04-27 11:46:59,220 - inference - INFO - Predictions for AIR.PA made successfully.
# 2025-04-27 11:46:59,292 - inference - INFO - Predictions for ALO.PA made successfully.
# 2025-04-27 11:46:59,368 - inference - INFO - Predictions for MT.AS made successfully.
# 2025-04-27 11:46:59,443 - inference - INFO - Predictions for CS.PA made successfully.
# 2025-04-27 11:46:59,516 - inference - INFO - Predictions for BNP.PA made successfully.
# 2025-04-27 11:46:59,586 - inference - INFO - Predictions for EN.PA made successfully.
# 2025-04-27 11:46:59,660 - inference - INFO - Predictions for CAP.PA made successfully.
# 2025-04-27 11:46:59,729 - inference - INFO - Predictions for CA.PA made successfully.
# 2025-04-27 11:46:59,801 - inference - INFO - Predictions for ACA.PA made successfully.
# 2025-04-27 11:46:59,870 - inference - INFO - Predictions for BN.PA made successfully.
# 2025-04-27 11:46:59,940 - inference - INFO - Predictions for DSY.PA made successfully.
# 2025-04-27 11:47:00,012 - inference - INFO - Predictions for EDEN.PA made successfully.
# 2025-04-27 11:47:00,085 - inference - INFO - Predictions for ENGI.PA made successfully.
# 2025-04-27 11:47:00,158 - inference - INFO - Predictions for EL.PA made successfully.
# 2025-04-27 11:47:00,235 - inference - INFO - Predictions for ERF.PA made successfully.
# 2025-04-27 11:47:00,308 - inference - INFO - Predictions for RMS.PA made successfully.
# 2025-04-27 11:47:00,397 - inference - INFO - Predictions for KER.PA made successfully.
# 2025-04-27 11:47:00,470 - inference - INFO - Predictions for OR.PA made successfully.
# 2025-04-27 11:47:00,546 - inference - INFO - Predictions for LR.PA made successfully.
# 2025-04-27 11:47:00,632 - inference - INFO - Predictions for MC.PA made successfully.
# 2025-04-27 11:47:00,706 - inference - INFO - Predictions for ML.PA made successfully.
# 2025-04-27 11:47:00,784 - inference - INFO - Predictions for ORA.PA made successfully.
# 2025-04-27 11:47:00,846 - inference - INFO - Predictions for RI.PA made successfully.
# 2025-04-27 11:47:00,914 - inference - INFO - Predictions for PUB.PA made successfully.
# 2025-04-27 11:47:00,985 - inference - INFO - Predictions for RNO.PA made successfully.
# 2025-04-27 11:47:01,052 - inference - INFO - Predictions for SAF.PA made successfully.
# 2025-04-27 11:47:01,131 - inference - INFO - Predictions for SGO.PA made successfully.
# 2025-04-27 11:47:01,212 - inference - INFO - Predictions for SAN.PA made successfully.
# 2025-04-27 11:47:01,285 - inference - INFO - Predictions for SU.PA made successfully.
# 2025-04-27 11:47:01,363 - inference - INFO - Predictions for GLE.PA made successfully.
# 2025-04-27 11:47:01,439 - inference - INFO - Predictions for STLAP.PA made successfully.
# 2025-04-27 11:47:01,514 - inference - INFO - Predictions for STMPA.PA made successfully.
# 2025-04-27 11:47:01,585 - inference - INFO - Predictions for TEP.PA made successfully.
# 2025-04-27 11:47:01,670 - inference - INFO - Predictions for HO.PA made successfully.
# 2025-04-27 11:47:01,744 - inference - INFO - Predictions for TTE.PA made successfully.
# 2025-04-27 11:47:01,814 - inference - INFO - Predictions for VIE.PA made successfully.
# 2025-04-27 11:47:01,885 - inference - INFO - Predictions for DG.PA made successfully.
# 2025-04-27 11:47:01,958 - inference - INFO - Predictions for SPY made successfully.
# 2025-04-27 11:47:02,027 - inference - INFO - Predictions for VOO made successfully.
# 2025-04-27 11:47:02,092 - inference - INFO - Predictions for IVV made successfully.
# 2025-04-27 11:47:02,167 - inference - INFO - Predictions for VTI made successfully.
# 2025-04-27 11:47:02,240 - inference - INFO - Predictions for QQQ made successfully.
# 2025-04-27 11:47:02,316 - inference - INFO - Predictions for VEA made successfully.
# 2025-04-27 11:47:02,391 - inference - INFO - Predictions for VUG made successfully.
# 2025-04-27 11:47:02,464 - inference - INFO - Predictions for VTV made successfully.
# 2025-04-27 11:47:02,539 - inference - INFO - Predictions for IEFA made successfully.
# 2025-04-27 11:47:02,607 - inference - INFO - Predictions for AGG made successfully.
# 2025-04-27 11:47:02,684 - inference - INFO - Predictions for BND made successfully.
# 2025-04-27 11:47:02,748 - inference - INFO - Predictions for IWF made successfully.
# 2025-04-27 11:47:02,816 - inference - INFO - Predictions for IJH made successfully.
# 2025-04-27 11:47:02,891 - inference - INFO - Predictions for VIG made successfully.
# 2025-04-27 11:47:02,961 - inference - INFO - Predictions for IJR made successfully.
# 2025-04-27 11:47:03,041 - inference - INFO - Predictions for IEMG made successfully.
# 2025-04-27 11:47:03,194 - inference - INFO - Predictions for VWO made successfully.
# 2025-04-27 11:47:03,259 - inference - INFO - Predictions for VXUS made successfully.
# 2025-04-27 11:47:03,335 - inference - INFO - Predictions for VGT made successfully.
# 2025-04-27 11:47:03,415 - inference - INFO - Predictions for GLD made successfully.
# 2025-04-27 11:47:03,490 - inference - INFO - Predictions for XLK made successfully.
# 2025-04-27 11:47:03,564 - inference - INFO - Predictions for VO made successfully.
# 2025-04-27 11:47:03,643 - inference - INFO - Predictions for IWM made successfully.
# 2025-04-27 11:47:03,715 - inference - INFO - Predictions for RSP made successfully.
# 2025-04-27 11:47:03,794 - inference - INFO - Predictions for ITOT made successfully.
# 2025-04-27 11:47:03,870 - inference - INFO - Predictions for SCHD made successfully.
# 2025-04-27 11:47:03,941 - inference - INFO - Predictions for TLT made successfully.
# 2025-04-27 11:47:04,015 - inference - INFO - Predictions for BNDX made successfully.
# 2025-04-27 11:47:04,091 - inference - INFO - Predictions for VB made successfully.
# 2025-04-27 11:47:04,162 - inference - INFO - Predictions for IWD made successfully.
# 2025-04-27 11:47:04,234 - inference - INFO - Predictions for VYM made successfully.
# 2025-04-27 11:47:04,308 - inference - INFO - Predictions for EFA made successfully.
# 2025-04-27 11:47:04,383 - inference - INFO - Predictions for IVW made successfully.
# 2025-04-27 11:47:04,456 - inference - INFO - Predictions for VCIT made successfully.
# 2025-04-27 11:47:04,525 - inference - INFO - Predictions for QUAL made successfully.
# 2025-04-27 11:47:04,600 - inference - INFO - Predictions for SCHX made successfully.
# 2025-04-27 11:47:04,674 - inference - INFO - Predictions for SPLG made successfully.
# 2025-04-27 11:47:04,746 - inference - INFO - Predictions for SCHF made successfully.
# 2025-04-27 11:47:04,820 - inference - INFO - Predictions for XLF made successfully.
# 2025-04-27 11:47:04,889 - inference - INFO - Predictions for XLV made successfully.
# 2025-04-27 11:47:04,963 - inference - INFO - Predictions for VEU made successfully.
# 2025-04-27 11:47:05,039 - inference - INFO - Predictions for VT made successfully.
# 2025-04-27 11:47:05,112 - inference - INFO - Predictions for IXUS made successfully.
# 2025-04-27 11:47:05,186 - inference - INFO - Predictions for MUB made successfully.
# 2025-04-27 11:47:05,264 - inference - INFO - Predictions for VNQ made successfully.
# 2025-04-27 11:47:05,337 - inference - INFO - Predictions for VV made successfully.
# 2025-04-27 11:47:05,413 - inference - INFO - Predictions for IWB made successfully.
# 2025-04-27 11:47:05,487 - inference - INFO - Predictions for IWR made successfully.
# 2025-04-27 11:47:05,555 - inference - INFO - Predictions for VCSH made successfully.
# 2025-04-27 11:47:05,632 - inference - INFO - Predictions for XLE made successfully.
# 2025-04-27 11:47:05,705 - inference - INFO - Predictions for DIA made successfully.
# 2025-04-27 11:47:05,779 - inference - INFO - Predictions for IVE made successfully.
# 2025-04-27 11:47:05,847 - inference - INFO - Predictions for IEF made successfully.
# 2025-04-27 11:47:05,919 - inference - INFO - Predictions for BSV made successfully.
# 2025-04-27 11:47:05,989 - inference - INFO - Predictions for BIL made successfully.
# 2025-04-27 11:47:06,067 - inference - INFO - Predictions for MBB made successfully.
# 2025-04-27 11:47:06,140 - inference - INFO - Predictions for SCHG made successfully.
# 2025-04-27 11:47:06,213 - inference - INFO - Predictions for IAU made successfully.
# 2025-04-27 11:47:06,280 - inference - INFO - Predictions for SCHB made successfully.
# 2025-04-27 11:47:06,355 - inference - INFO - Predictions for VGIT made successfully.
# 2025-04-27 11:47:06,432 - inference - INFO - Predictions for LQD made successfully.
# 2025-04-27 11:47:06,506 - inference - INFO - Predictions for VBR made successfully.
# 2025-04-27 11:47:06,581 - inference - INFO - Predictions for SPYG made successfully.
# 2025-04-27 11:47:06,654 - inference - INFO - Predictions for GOVT made successfully.
# 2025-04-27 11:47:06,723 - inference - INFO - Predictions for USMV made successfully.
# 2025-04-27 11:47:06,798 - inference - INFO - Predictions for SPYV made successfully.
# 2025-04-27 11:47:06,869 - inference - INFO - Predictions for TQQQ made successfully.
# 2025-04-27 11:47:06,957 - inference - INFO - Predictions for SMH made successfully.
# 2025-04-27 11:47:07,033 - inference - INFO - Predictions for SHY made successfully.
# 2025-04-27 11:47:07,110 - inference - INFO - Predictions for MDY made successfully.
# 2025-04-27 11:47:07,194 - inference - INFO - Predictions for MGK made successfully.
# 2025-04-27 11:47:07,281 - inference - INFO - Predictions for VONG made successfully.
# 2025-04-27 11:47:07,357 - inference - INFO - Predictions for SPDW made successfully.
# 2025-04-27 11:47:07,435 - inference - INFO - Predictions for IGSB made successfully.
# 2025-04-27 11:47:07,513 - inference - INFO - Predictions for SDY made successfully.
# 2025-04-27 11:47:07,582 - inference - INFO - Predictions for VGSH made successfully.
# 2025-04-27 11:47:07,654 - inference - INFO - Predictions for VXF made successfully.
# 2025-04-27 11:47:07,730 - inference - INFO - Predictions for BIV made successfully.
# 2025-04-27 11:47:07,810 - inference - INFO - Predictions for DVY made successfully.
# 2025-04-27 11:47:07,897 - inference - INFO - Predictions for IUSG made successfully.
# 2025-04-27 11:47:07,977 - inference - INFO - Predictions for VGK made successfully.
# 2025-04-27 11:47:08,050 - inference - INFO - Predictions for EFV made successfully.
# 2025-04-27 11:47:08,134 - inference - INFO - Predictions for XLI made successfully.
# 2025-04-27 11:47:08,204 - inference - INFO - Predictions for SHV made successfully.
# 2025-04-27 11:47:08,279 - inference - INFO - Predictions for XLY made successfully.
# 2025-04-27 11:47:08,352 - inference - INFO - Predictions for ACWI made successfully.
# 2025-04-27 11:47:08,420 - inference - INFO - Predictions for IUSV made successfully.
# 2025-04-27 11:47:08,498 - inference - INFO - Predictions for IYW made successfully.
# 2025-04-27 11:47:08,571 - inference - INFO - Predictions for VHT made successfully.
